# %% [markdown]
# ### Training and testing mask

# %% [markdown]
# step_1: play the original audio
#
# step_2: play the masked audio(which mask is generate by ourself)
#
# step_3: play the predicted masked mask audio(which mask is predicted by the neural network)

# %%
# import part
import numpy as np
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import RMSprop
from keras import backend as K
import matplotlib.pyplot as plt

# download data
X_train = spec_train = np.loadtxt("clean_spec_train_1000.txt")

y_train = clean_mask = np.loadtxt("clean_mask_train_1000.txt")
# Out:
# /home/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# No hiden layer. just fully connected
# sigmoid as activation function
model = Sequential([
    Dense(2470, input_dim=2470),
    Activation('sigmoid'),  # ,sigmoid softmax
    #Dense(247),
    #Activation('relu'),
    #Dense(2470),
    #Activation('sigmoid')
])

# %%
# optimizer

rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-8, decay=0.0)


def mean_pred(y_true, y_pred):
    return K.mean(y_pred)


model.compile(
    optimizer=rmsprop,
    loss='mean_squared_error',
    metrics=['accuracy']  # , mean_pred]
)
print('Train-------------------------')

history = model.fit(X_train, y_train, validation_split=0.25, epochs=10000, batch_size=75, verbose=1)

# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

get_3rd_layer_output = K.function([model.layers[0].input],
                                  [model.layers[2].output])
layer_output1 = get_3rd_layer_output([spec_train])[0]

print(layer_output1)
# Out:
# Train-------------------------
# Train on 750 samples, validate on 250 samples
# Epoch 1/10000
# 750/750 [==============================] - 1s 935us/step - loss: 0.1505 - acc: 0.0013 - val_loss: 0.0992 - val_acc: 0.0040
# Epoch 2/10000
# 750/750 [==============================] - 0s 193us/step - loss: 0.0900 - acc: 0.0040 - val_loss: 0.0713 - val_acc: 0.0080
# Epoch 3/10000
# 750/750 [==============================] - 0s 190us/step - loss: 0.0693 - acc: 0.0040 - val_loss: 0.0566 - val_acc: 0.0040
# Epoch 4/10000
# 750/750 [==============================] - 0s 196us/step - loss: 0.0572 - acc: 0.0067 - val_loss: 0.0473 - val_acc: 0.0040
# Epoch 5/10000
# 750/750 [==============================] - 0s 192us/step - loss: 0.0491 - acc: 0.0053 - val_loss: 0.0409 - val_acc: 0.0040
# Epoch 6/10000
# 750/750 [==============================] - 0s 194us/step - loss: 0.0434 - acc: 0.0053 - val_loss: 0.0364 - val_acc: 0.0040
# Epoch 7/10000
# ...

# %%
get_3rd_layer_output = K.function([model.layers[0].input],
                                  [model.layers[1].output])
layer_output1 = get_3rd_layer_output([spec_train])[0]

print(layer_output1)
# Out:
# [[9.34113409e-09 1.08141220e-08 6.55340715e-09 ... 6.06944806e-09
#   1.06942284e-16 4.56163969e-13]
#  [2.71036583e-07 2.91842753e-07 2.94314049e-07 ... 2.68386231e-07
#   1.26716259e-05 1.61729386e-05]
#  [3.71172433e-07 3.81970267e-07 3.22271802e-07 ... 3.32865369e-07
#   4.47022273e-07 6.64504114e-07]
#  ...
#  [1.22152854e-09 1.14054821e-09 1.00660125e-09 ... 9.85019732e-10
#   2.35440389e-10 1.37619682e-09]
#  [3.26938789e-05 3.27824237e-05 3.09903880e-05 ... 3.12551601e-05
#   4.61897173e-07 1.89557329e-06]
#  [8.67690460e-07 9.05259014e-07 8.60675357e-07 ... 8.02428247e-07
#   1.02274997e-08 4.25486277e-08]]

# %%
layer_output1.max()
# Out:
# 1.0

# %%
layer_output1.mean()
# Out:
# 0.03695931

# %%
layer_output1.size
# Out:
# 2470000

# %%
x_pred = model.predict(X_train)
print('prediction of the model', x_pred)
print('prediction size', x_pred.size)
# Out:
# prediction of the model [[9.34127620e-09 1.08140190e-08 6.55336940e-09 ... 6.06945960e-09
#   1.06942284e-16 4.56164837e-13]
#  [2.71032434e-07 2.91844657e-07 2.94317715e-07 ... 2.68387765e-07
#   1.26716977e-05 1.61729386e-05]
#  [3.71163253e-07 3.81968078e-07 3.22273621e-07 ... 3.32870457e-07
#   4.47025229e-07 6.64503489e-07]
#  ...
#  [1.22150989e-09 1.14057219e-09 1.00661091e-09 ... 9.85017845e-10
#   2.35440389e-10 1.37621781e-09]
#  [3.26940681e-05 3.27822345e-05 3.09905045e-05 ... 3.12551892e-05
#   4.61900697e-07 1.89561308e-06]
#  [8.67685571e-07 9.05266802e-07 8.60656485e-07 ... 8.02429781e-07
#   1.02274020e-08 4.25488764e-08]]
# prediction size 2470000

# %%
x_pred = model.predict(X_train[0:500])
print('prediction of the model', x_pred)
print('prediction size', x_pred.size)
# Out:
# prediction of the model [[9.34127620e-09 1.08140190e-08 6.55336940e-09 ... 6.06945960e-09
#   1.06942284e-16 4.56164837e-13]
#  [2.71032434e-07 2.91844657e-07 2.94317715e-07 ... 2.68387765e-07
#   1.26716977e-05 1.61729386e-05]
#  [3.71163253e-07 3.81968078e-07 3.22273621e-07 ... 3.32870457e-07
#   4.47025229e-07 6.64503489e-07]
#  ...
#  [7.37245571e-08 7.81336240e-08 7.06918613e-08 ... 7.67809638e-08
#   3.62205839e-07 2.09188741e-07]
#  [3.50239645e-07 3.50759422e-07 3.78178527e-07 ... 3.60218905e-07
#   2.09614910e-07 3.26216139e-08]
#  [1.16735272e-07 1.18026968e-07 1.17112393e-07 ... 1.25864887e-07
#   5.20342212e-07 3.58924439e-07]]
# prediction size 1235000

# %%
x_pred = model.predict(X_train[0:1000])
print('prediction of the model', x_pred)
print('prediction size', x_pred.size)
# Out:
# prediction of the model [[9.34127620e-09 1.08140190e-08 6.55336940e-09 ... 6.06945960e-09
#   1.06942284e-16 4.56164837e-13]
#  [2.71032434e-07 2.91844657e-07 2.94317715e-07 ... 2.68387765e-07
#   1.26716977e-05 1.61729386e-05]
#  [3.71163253e-07 3.81968078e-07 3.22273621e-07 ... 3.32870457e-07
#   4.47025229e-07 6.64503489e-07]
#  ...
#  [1.22150989e-09 1.14057219e-09 1.00661091e-09 ... 9.85017845e-10
#   2.35440389e-10 1.37621781e-09]
#  [3.26940681e-05 3.27822345e-05 3.09905045e-05 ... 3.12551892e-05
#   4.61900697e-07 1.89561308e-06]
#  [8.67685571e-07 9.05266802e-07 8.60656485e-07 ... 8.02429781e-07
#   1.02274020e-08 4.25488764e-08]]
# prediction size 2470000

# %%
x_mask = x_pred.reshape(247,10000)
plt.imshow(abs(x_mask[:, : int(512 / 2 + 1)].T), aspect = "auto", cmap=plt.cm.afmhot, origin = "lower")
plt.title("Mask", fontsize = 20)
plt.show()

# %%
y_mask = y_train.reshape(247,10000)
plt.imshow(abs(y_mask[:, : int(512 / 2 + 1)].T), aspect = "auto", cmap=plt.cm.afmhot, origin = "lower")
plt.title("Mask", fontsize = 20)
plt.show()
