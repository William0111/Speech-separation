# %% [markdown]
# # Simple RNN test by data-10*512
# # 10000 steps with lr = 0.001
# # cell_size = 500

# %% [markdown]
# Results are better than 2000&1200, and still can improve with more epochs
# best run:
#             train_cost:  1228.822021484375 train_accuracy:  0.19300000369548798
#             test cost:  2082.856689453125 test accuracy:  0.12700000405311584

# %%
import numpy as np

np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import SimpleRNN, Activation, Dense, Flatten
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.optimizers import RMSprop

TIME_STEPS = 10
INPUT_SIZE = 512
BATCH_SIZE = 50
BATCH_INDEX = 0
OUTPUT_SIZE = 5120
CELL_SIZE = 500
LR = 0.001


           
           
# loading data
X_train = np.loadtxt("0131_spec_train_1000*5120.txt")
y_train = np.loadtxt("0131_mask_train_1000*5120.txt")

X_test = np.loadtxt("0131_spec_test_1000*5120.txt")
y_test = np.loadtxt("0131_mask_test_1000*5120.txt")

# batch_size=y_test.shape[0]

# data pre-processing
X_train = X_train.reshape(-1, 10, 512)
#y_train = y_train.reshape(-1, 3, 512)
X_test = X_test.reshape(-1, 10, 512)
#y_test = y_test.reshape(-1, 3, 512)

#  build RNN model
model = Sequential()

# RNN cell

model.add(SimpleRNN(
    batch_input_shape=(None, TIME_STEPS, INPUT_SIZE),
    # input_dim=INPUT_SIZE,
    # input_length=TIME_STEPS,
    output_dim=CELL_SIZE,
    unroll=True
))

# output layer
#model.add(Flatten())
model.add(Dense(OUTPUT_SIZE))
model.add(Activation('hard_sigmoid'))

# # optimizer
#
adam = Adam(LR)

#optimizer
#rmsprop = RMSprop(lr=0.0001, rho=0.9, epsilon=1e-8, decay=0.0)

model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# # training
#

for step in range(10001):
    # data shape = (batch_num, steps, inputs/outputs)
    X_batch = X_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :, :]
    Y_batch = y_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :]
    cost = model.train_on_batch(X_batch, Y_batch)
    BATCH_INDEX += BATCH_SIZE
    BATCH_INDEX = 0 if BATCH_INDEX >= X_train.shape[0] else BATCH_INDEX

    if step % 500 == 0:
        print('Next_Train----------: step = ', step)
        train_cost, train_accuracy = model.evaluate(X_train, y_train, batch_size=y_train.shape[0], verbose=False)
        print('train_cost: ', train_cost, 'train_accuracy: ', train_accuracy)
        cost, accuracy = model.evaluate(X_test, y_test, batch_size=y_test.shape[0], verbose=False)
        print('test cost: ', cost, 'test accuracy: ', accuracy)
        
       

# print('Train-------------------------')
#
# history = model.fit(X_train, y_train, validation_split=0.25, epochs=3100, shuffle=True, batch_size=75, verbose=1)
#
# # Plot training & validation accuracy values
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# # Plot training & validation loss values
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# get_3rd_layer_output = K.function([model.layers[0].input],
#                                   [model.layers[1].output])
# layer_output1 = get_3rd_layer_output([X_train])[0]
#
# print(layer_output1)
# Out:
# /home/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/william/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: Update your `SimpleRNN` call to the Keras 2 API: `SimpleRNN(batch_input_shape=(None, 10,..., unroll=True, units=500)`
# Next_Train----------: step =  0
# train_cost:  1662.6285400390625 train_accuracy:  0.0010000000474974513
# test cost:  1986.8646240234375 test accuracy:  0.0
# Next_Train----------: step =  500
# train_cost:  1460.616455078125 train_accuracy:  0.11299999803304672
# test cost:  1793.3006591796875 test accuracy:  0.1469999998807907
# Next_Train----------: step =  1000
# train_cost:  1423.294189453125 train_accuracy:  0.12099999934434891
# test cost:  1787.6826171875 test accuracy:  0.09200000017881393
# Next_Train----------: step =  1500
# train_cost:  1393.8134765625 train_accuracy:  0.09099999815225601
# test cost:  1772.195556640625 test accuracy:  0.09700000286102295
# Next_Train----------: step =  2000
# train_cost:  1386.0452880859375 train_accuracy:  0.12600000202655792
# test cost:  1787.983642578125 test accuracy:  0.09799999743700027
# Next_Train----------: step =  2500
# train_cost:  1376.6427001953125 train_accuracy:  0.11400000005960464
# test cost:  1789.6337890625 test accuracy:  0.11999999731779099
# Next_Train----------: step =  3000
# train_cost:  1356.8587646484375 train_accuracy:  0.13199999928474426
# test cost:  1822.7662353515625 test accuracy:  0.11900000274181366
# Next_Train----------: step =  3500
# train_cost:  1328.398193359375 train_accuracy:  0.13600000739097595
# test cost:  1861.2657470703125 test accuracy:  0.14499999582767487
# Next_Train----------: step =  4000
# train_cost:  1327.6832275390625 train_accuracy:  0.12399999797344208
# test cost:  1845.516845703125 test accuracy:  0.1420000046491623
# Next_Train----------: step =  4500
# train_cost:  1296.810546875 train_accuracy:  0.1340000033378601
# test cost:  1918.5362548828125 test accuracy:  0.15299999713897705
# Next_Train----------: step =  5000
# train_cost:  1336.9345703125 train_accuracy:  0.0949999988079071
# test cost:  1856.2919921875 test accuracy:  0.06700000166893005
# Next_Train----------: step =  5500
# train_cost:  1310.891357421875 train_accuracy:  0.15299999713897705
# test cost:  1885.36572265625 test accuracy:  0.09300000220537186
# Next_Train----------: step =  6000
# train_cost:  1259.5355224609375 train_accuracy:  0.14900000393390656
# test cost:  2022.70703125 test accuracy:  0.07900000363588333
# Next_Train----------: step =  6500
# train_cost:  1286.418701171875 train_accuracy:  0.14800000190734863
# test cost:  1938.697509765625 test accuracy:  0.06499999761581421
# Next_Train----------: step =  7000
# train_cost:  1245.489501953125 train_accuracy:  0.14900000393390656
# test cost:  2040.7347412109375 test accuracy:  0.08500000089406967
# Next_Train----------: step =  7500
# train_cost:  1287.2320556640625 train_accuracy:  0.16500000655651093
# test cost:  1943.27197265625 test accuracy:  0.13099999725818634
# Next_Train----------: step =  8000
# train_cost:  1295.1121826171875 train_accuracy:  0.12600000202655792
# test cost:  1934.406982421875 test accuracy:  0.0989999994635582
# Next_Train----------: step =  8500
# train_cost:  1232.9520263671875 train_accuracy:  0.17800000309944153
# test cost:  2077.70654296875 test accuracy:  0.14000000059604645
# Next_Train----------: step =  9000
# train_cost:  1288.5350341796875 train_accuracy:  0.15000000596046448
# test cost:  1923.4095458984375 test accuracy:  0.12700000405311584
# Next_Train----------: step =  9500
# train_cost:  1236.0733642578125 train_accuracy:  0.15700000524520874
# test cost:  2118.747314453125 test accuracy:  0.10000000149011612
# Next_Train----------: step =  10000
# train_cost:  1228.822021484375 train_accuracy:  0.19300000369548798
# test cost:  2082.856689453125 test accuracy:  0.12700000405311584
