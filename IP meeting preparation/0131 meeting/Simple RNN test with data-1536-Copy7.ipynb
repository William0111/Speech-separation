# %% [markdown]
# # Simple RNN test by data-10*512
# # 50000 steps with lr = 0.001
# # cell_size = 800

# %% [markdown]
# Results are better than
# best run:

# %%
import numpy as np

np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import SimpleRNN, Activation, Dense, Flatten
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.optimizers import RMSprop

TIME_STEPS = 10
INPUT_SIZE = 512
BATCH_SIZE = 50
BATCH_INDEX = 0
OUTPUT_SIZE = 5120
CELL_SIZE = 800
LR = 0.001


           
           
# loading data
X_train = np.loadtxt("0131_spec_train_1000*5120.txt")
y_train = np.loadtxt("0131_mask_train_1000*5120.txt")

X_test = np.loadtxt("0131_spec_test_1000*5120.txt")
y_test = np.loadtxt("0131_mask_test_1000*5120.txt")

# batch_size=y_test.shape[0]

# data pre-processing
X_train = X_train.reshape(-1, 10, 512)
#y_train = y_train.reshape(-1, 3, 512)
X_test = X_test.reshape(-1, 10, 512)
#y_test = y_test.reshape(-1, 3, 512)

#  build RNN model
model = Sequential()

# RNN cell

model.add(SimpleRNN(
    batch_input_shape=(None, TIME_STEPS, INPUT_SIZE),
    # input_dim=INPUT_SIZE,
    # input_length=TIME_STEPS,
    output_dim=CELL_SIZE,
    unroll=True
))

# output layer
#model.add(Flatten())
model.add(Dense(OUTPUT_SIZE))
model.add(Activation('hard_sigmoid'))

# # optimizer
#
adam = Adam(LR)

#optimizer
#rmsprop = RMSprop(lr=0.0001, rho=0.9, epsilon=1e-8, decay=0.0)

model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# # training
#

for step in range(50001):
    # data shape = (batch_num, steps, inputs/outputs)
    X_batch = X_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :, :]
    Y_batch = y_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :]
    cost = model.train_on_batch(X_batch, Y_batch)
    BATCH_INDEX += BATCH_SIZE
    BATCH_INDEX = 0 if BATCH_INDEX >= X_train.shape[0] else BATCH_INDEX

    if step % 500 == 0:
        print('Next_Train----------: step = ', step)
        train_cost, train_accuracy = model.evaluate(X_train, y_train, batch_size=y_train.shape[0], verbose=False)
        print('train_cost: ', train_cost, 'train_accuracy: ', train_accuracy)
        cost, accuracy = model.evaluate(X_test, y_test, batch_size=y_test.shape[0], verbose=False)
        print('test cost: ', cost, 'test accuracy: ', accuracy)
        
       

# print('Train-------------------------')
#
# history = model.fit(X_train, y_train, validation_split=0.25, epochs=3100, shuffle=True, batch_size=75, verbose=1)
#
# # Plot training & validation accuracy values
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# # Plot training & validation loss values
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# get_3rd_layer_output = K.function([model.layers[0].input],
#                                   [model.layers[1].output])
# layer_output1 = get_3rd_layer_output([X_train])[0]
#
# print(layer_output1)
# Out:
# /home/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/william/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: Update your `SimpleRNN` call to the Keras 2 API: `SimpleRNN(batch_input_shape=(None, 10,..., unroll=True, units=800)`
# Next_Train----------: step =  0
# train_cost:  1659.105224609375 train_accuracy:  0.0
# test cost:  1982.7257080078125 test accuracy:  0.0
# Next_Train----------: step =  500
# train_cost:  1673.6585693359375 train_accuracy:  0.1120000034570694
# test cost:  2055.85400390625 test accuracy:  0.14800000190734863
# Next_Train----------: step =  1000
# train_cost:  1687.9493408203125 train_accuracy:  0.1120000034570694
# test cost:  2067.79345703125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  1500
# train_cost:  1692.960205078125 train_accuracy:  0.1120000034570694
# test cost:  2072.158203125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  2000
# train_cost:  1694.9287109375 train_accuracy:  0.1120000034570694
# test cost:  2073.57568359375 test accuracy:  0.14800000190734863
# Next_Train----------: step =  2500
# train_cost:  1696.1419677734375 train_accuracy:  0.1120000034570694
# test cost:  2074.045166015625 test accuracy:  0.14800000190734863
# Next_Train----------: step =  3000
# train_cost:  1697.0811767578125 train_accuracy:  0.1120000034570694
# test cost:  2075.473876953125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  3500
# train_cost:  1697.2933349609375 train_accuracy:  0.1120000034570694
# test cost:  2075.8408203125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  4000
# train_cost:  1699.44677734375 train_accuracy:  0.1120000034570694
# test cost:  2078.05908203125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  4500
# train_cost:  1701.1297607421875 train_accuracy:  0.1120000034570694
# test cost:  2078.853759765625 test accuracy:  0.14800000190734863
# Next_Train----------: step =  5000
# train_cost:  1708.338623046875 train_accuracy:  0.1120000034570694
# test cost:  2081.049072265625 test accuracy:  0.14800000190734863
# Next_Train----------: step =  5500
# train_cost:  1801.6627197265625 train_accuracy:  0.09700000286102295
# test cost:  2152.533447265625 test accuracy:  0.13500000536441803
# Next_Train----------: step =  6000
# train_cost:  1859.9825439453125 train_accuracy:  0.08699999749660492
# test cost:  2268.91943359375 test accuracy:  0.13600000739097595
# Next_Train----------: step =  6500
# train_cost:  2156.03271484375 train_accuracy:  0.07000000029802322
# test cost:  2644.7265625 test accuracy:  0.11100000143051147
# Next_Train----------: step =  7000
# train_cost:  2158.008056640625 train_accuracy:  0.0689999982714653
# test cost:  2651.193603515625 test accuracy:  0.1120000034570694
# Next_Train----------: step =  7500
# train_cost:  2175.25927734375 train_accuracy:  0.11500000208616257
# test cost:  2678.97998046875 test accuracy:  0.15800000727176666
# Next_Train----------: step =  8000
# train_cost:  1795.553466796875 train_accuracy:  0.11100000143051147
# test cost:  2202.1669921875 test accuracy:  0.14800000190734863
# Next_Train----------: step =  8500
# train_cost:  1797.463623046875 train_accuracy:  0.11100000143051147
# test cost:  2204.952392578125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  9000
# train_cost:  1797.432373046875 train_accuracy:  0.11100000143051147
# test cost:  2204.891845703125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  9500
# train_cost:  1794.6065673828125 train_accuracy:  0.11100000143051147
# test cost:  2202.15185546875 test accuracy:  0.14800000190734863
# Next_Train----------: step =  10000
# train_cost:  1795.1668701171875 train_accuracy:  0.1120000034570694
# test cost:  2202.641845703125 test accuracy:  0.14800000190734863
# Next_Train----------: step =  10500
# train_cost:  1795.2642822265625 train_accuracy:  0.1120000034570694
# test cost:  2202.81591796875 test accuracy:  0.14800000190734863
# Next_Train----------: step =  11000
# train_cost:  1795.395751953125 train_accuracy:  0.1120000034570694
# test cost:  2202.86865234375 test accuracy:  0.14800000190734863
# Next_Train----------: step =  11500
# train_cost:  1795.4923095703125 train_accuracy:  0.1120000034570694
# test cost:  2203.1181640625 test accuracy:  0.14800000190734863
# Next_Train----------: step =  12000
# train_cost:  1795.426513671875 train_accuracy:  0.11299999803304672
# test cost:  2203.197509765625 test accuracy:  0.15000000596046448
# Next_Train----------: step =  12500
# train_cost:  1795.4991455078125 train_accuracy:  0.11299999803304672
# test cost:  2203.533935546875 test accuracy:  0.1509999930858612
# Next_Train----------: step =  13000
# train_cost:  1795.7562255859375 train_accuracy:  0.1120000034570694
# test cost:  2203.596435546875 test accuracy:  0.14800000190734863
# Next_Train----------: step =  13500
# train_cost:  1795.728759765625 train_accuracy:  0.1120000034570694
# test cost:  2203.74169921875 test accuracy:  0.14800000190734863
# Next_Train----------: step =  14000
# train_cost:  1795.8934326171875 train_accuracy:  0.02199999988079071
# test cost:  2203.6201171875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  14500
# train_cost:  1797.0772705078125 train_accuracy:  0.02199999988079071
# test cost:  2205.07421875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  15000
# train_cost:  1797.2049560546875 train_accuracy:  0.02199999988079071
# test cost:  2204.87451171875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  15500
# train_cost:  1797.73193359375 train_accuracy:  0.02199999988079071
# test cost:  2205.35888671875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  16000
# train_cost:  1798.039306640625 train_accuracy:  0.02199999988079071
# test cost:  2205.751220703125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  16500
# train_cost:  1798.124267578125 train_accuracy:  0.02199999988079071
# test cost:  2205.990966796875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  17000
# train_cost:  1798.36181640625 train_accuracy:  0.02199999988079071
# test cost:  2206.3330078125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  17500
# train_cost:  1799.072021484375 train_accuracy:  0.023000000044703484
# test cost:  2207.237060546875 test accuracy:  0.028999999165534973
# Next_Train----------: step =  18000
# train_cost:  1803.012451171875 train_accuracy:  0.02199999988079071
# test cost:  2211.80322265625 test accuracy:  0.02800000086426735
# Next_Train----------: step =  18500
# train_cost:  1804.151123046875 train_accuracy:  0.02199999988079071
# test cost:  2213.112548828125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  19000
# train_cost:  1805.3995361328125 train_accuracy:  0.02199999988079071
# test cost:  2214.6171875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  19500
# train_cost:  1805.40576171875 train_accuracy:  0.02199999988079071
# test cost:  2214.625732421875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  20000
# train_cost:  1805.787841796875 train_accuracy:  0.02199999988079071
# test cost:  2215.060546875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  20500
# train_cost:  1806.1151123046875 train_accuracy:  0.02199999988079071
# test cost:  2215.4423828125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  21000
# train_cost:  1806.1156005859375 train_accuracy:  0.02199999988079071
# test cost:  2215.439697265625 test accuracy:  0.02800000086426735
# Next_Train----------: step =  21500
# train_cost:  1806.1121826171875 train_accuracy:  0.02199999988079071
# test cost:  2215.4365234375 test accuracy:  0.02800000086426735
# Next_Train----------: step =  22000
# train_cost:  1806.1173095703125 train_accuracy:  0.02199999988079071
# test cost:  2215.4443359375 test accuracy:  0.02800000086426735
# Next_Train----------: step =  22500
# train_cost:  1806.116943359375 train_accuracy:  0.02199999988079071
# test cost:  2215.444580078125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  23000
# train_cost:  1806.113525390625 train_accuracy:  0.02199999988079071
# test cost:  2215.44287109375 test accuracy:  0.02800000086426735
# Next_Train----------: step =  23500
# train_cost:  1806.1109619140625 train_accuracy:  0.02199999988079071
# test cost:  2215.429443359375 test accuracy:  0.02800000086426735
# Next_Train----------: step =  24000
# train_cost:  1806.11474609375 train_accuracy:  0.02199999988079071
# test cost:  2215.441162109375 test accuracy:  0.02800000086426735
# Next_Train----------: step =  24500
# train_cost:  1806.114501953125 train_accuracy:  0.02199999988079071
# test cost:  2215.44189453125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  25000
# train_cost:  1806.114501953125 train_accuracy:  0.02199999988079071
# test cost:  2215.44091796875 test accuracy:  0.02800000086426735
# Next_Train----------: step =  25500
# train_cost:  1806.5052490234375 train_accuracy:  0.02199999988079071
# test cost:  2215.815673828125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  26000
# train_cost:  1806.4852294921875 train_accuracy:  0.02199999988079071
# test cost:  2216.0439453125 test accuracy:  0.02800000086426735
# Next_Train----------: step =  26500
# train_cost:  1807.5281982421875 train_accuracy:  0.024000000208616257
# test cost:  2217.230712890625 test accuracy:  0.03200000151991844
# Next_Train----------: step =  27000
# train_cost:  1808.07080078125 train_accuracy:  0.027000000700354576
# test cost:  2217.95703125 test accuracy:  0.03200000151991844
# Next_Train----------: step =  27500
# train_cost:  1839.6077880859375 train_accuracy:  0.024000000208616257
# test cost:  2265.868896484375 test accuracy:  0.03099999949336052
# Next_Train----------: step =  28000
# train_cost:  1839.0738525390625 train_accuracy:  0.20399999618530273
# test cost:  2264.9765625 test accuracy:  0.2409999966621399
# Next_Train----------: step =  28500
# train_cost:  1887.3115234375 train_accuracy:  0.1850000023841858
# test cost:  2303.232421875 test accuracy:  0.22100000083446503
# Next_Train----------: step =  29000
# train_cost:  1884.371337890625 train_accuracy:  0.19099999964237213
# test cost:  2301.51171875 test accuracy:  0.2240000069141388
# Next_Train----------: step =  29500
# train_cost:  1884.5069580078125 train_accuracy:  0.19099999964237213
# test cost:  2301.641845703125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  30000
# train_cost:  1884.5068359375 train_accuracy:  0.19099999964237213
# test cost:  2301.642578125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  30500
# train_cost:  1884.48193359375 train_accuracy:  0.19099999964237213
# test cost:  2301.572998046875 test accuracy:  0.2240000069141388
# Next_Train----------: step =  31000
# train_cost:  1884.4833984375 train_accuracy:  0.19099999964237213
# test cost:  2301.575439453125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  31500
# train_cost:  1884.4832763671875 train_accuracy:  0.19099999964237213
# test cost:  2301.575439453125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  32000
# train_cost:  1884.483154296875 train_accuracy:  0.19099999964237213
# test cost:  2301.575439453125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  32500
# train_cost:  1884.4833984375 train_accuracy:  0.19099999964237213
# test cost:  2301.575439453125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  33000
# train_cost:  1884.4832763671875 train_accuracy:  0.19099999964237213
# test cost:  2301.575439453125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  33500
# train_cost:  1884.483154296875 train_accuracy:  0.19099999964237213
# test cost:  2301.5751953125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  34000
# train_cost:  1884.4832763671875 train_accuracy:  0.19099999964237213
# test cost:  2301.575439453125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  34500
# train_cost:  1884.4832763671875 train_accuracy:  0.19099999964237213
# test cost:  2301.575927734375 test accuracy:  0.2240000069141388
# Next_Train----------: step =  35000
# train_cost:  1884.4830322265625 train_accuracy:  0.19099999964237213
# test cost:  2301.575927734375 test accuracy:  0.2240000069141388
# Next_Train----------: step =  35500
# train_cost:  1884.4833984375 train_accuracy:  0.19099999964237213
# test cost:  2301.57470703125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  36000
# train_cost:  1884.482177734375 train_accuracy:  0.19099999964237213
# test cost:  2301.573974609375 test accuracy:  0.2240000069141388
# Next_Train----------: step =  36500
# train_cost:  1884.48046875 train_accuracy:  0.19099999964237213
# test cost:  2301.573486328125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  37000
# train_cost:  1884.4794921875 train_accuracy:  0.19099999964237213
# test cost:  2301.577392578125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  37500
# train_cost:  1884.4752197265625 train_accuracy:  0.19099999964237213
# test cost:  2301.566650390625 test accuracy:  0.2240000069141388
# Next_Train----------: step =  38000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  38500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  39000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  39500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  40000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  40500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  41000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  41500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  42000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  42500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  43000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  43500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  44000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  44500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  45000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  45500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  46000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  46500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  47000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  47500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  48000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  48500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  49000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  49500
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
# Next_Train----------: step =  50000
# train_cost:  1884.5289306640625 train_accuracy:  0.19099999964237213
# test cost:  2301.60205078125 test accuracy:  0.2240000069141388
