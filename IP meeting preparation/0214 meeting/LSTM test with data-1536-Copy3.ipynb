# %% [markdown]
# # Simple RNN test by data-3*512
# # 5000 steps with lr = 0.01 (relatively big learning rate)

# %% [markdown]
# Results are better than
# best run:

# %%
import numpy as np

np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import SimpleRNN, Activation, Dense, Flatten,LSTM, TimeDistributed
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.optimizers import RMSprop

TIME_STEPS = 3
INPUT_SIZE = 512
BATCH_SIZE = 50
BATCH_INDEX = 0
OUTPUT_SIZE = 1536
#CELL_SIZE = 800
LR = 0.01


           
           
# loading data
X_train = np.loadtxt("0126_spec_train_1000.txt")
y_train = np.loadtxt("0126_mask_train_1000.txt")

X_test = np.loadtxt("0126_spec_test_1000.txt")
y_test = np.loadtxt("0126_mask_test_1000.txt")

# batch_size=y_test.shape[0]

# data pre-processing
X_train = X_train.reshape(-1, 3, 512)
#y_train = y_train.reshape(-1, 3, 512)
X_test = X_test.reshape(-1, 3, 512)
#y_test = y_test.reshape(-1, 3, 512)

#  build RNN model
model = Sequential()

# RNN cell

model.add(LSTM(
    units =500,
    batch_input_shape=( BATCH_SIZE, TIME_STEPS, INPUT_SIZE),
    #input_dim=INPUT_SIZE,
    #input_length=TIME_STEPS,
    #output_dim=CELL_SIZE,
    #return_sequences=True,
    #stateful=True 
    unroll=True
))

# output layer
#model.add(Flatten())
model.add((Dense(OUTPUT_SIZE)))  #TimeDistributed
#model.add(Activation('hard_sigmoid'))

# # optimizer
#
adam = Adam(LR)

#optimizer
#rmsprop = RMSprop(lr=0.0001, rho=0.9, epsilon=1e-8, decay=0.0)

model.compile(optimizer=adam,
              loss='mse',
              metrics=['accuracy'])

# # training
#

for step in range(5001):
    # data shape = (batch_num, steps, inputs/outputs)
    X_batch = X_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :, :]
    Y_batch = y_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :]
    cost = model.train_on_batch(X_batch, Y_batch)
    BATCH_INDEX += BATCH_SIZE
    BATCH_INDEX = 0 if BATCH_INDEX >= X_train.shape[0] else BATCH_INDEX

    if step % 50 == 0:
        print('Next_Train----------: step = ', step)
        train_cost, train_accuracy = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=False)
        print('train_cost: ', train_cost, 'train_accuracy: ', train_accuracy)
        cost, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=False)
        print('test cost: ', cost, 'test accuracy: ', accuracy)
        
       

# print('Train-------------------------')
#
# history = model.fit(X_train, y_train, validation_split=0.25, epochs=3100, shuffle=True, batch_size=75, verbose=1)
#
# # Plot training & validation accuracy values
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# # Plot training & validation loss values
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# get_3rd_layer_output = K.function([model.layers[0].input],
#                                   [model.layers[1].output])
# layer_output1 = get_3rd_layer_output([X_train])[0]
#
# print(layer_output1)
# Out:
# /home/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Next_Train----------: step =  0
# train_cost:  0.035473409481346606 train_accuracy:  0.0009999999776482583
# test cost:  0.042493453808128835 test accuracy:  0.0009999999776482583
# Next_Train----------: step =  50
# train_cost:  0.019488173769786954 train_accuracy:  0.015999999642372132
# test cost:  0.02804133263416588 test accuracy:  0.008999999798834323
# Next_Train----------: step =  100
# train_cost:  0.016692188521847128 train_accuracy:  0.01699999962002039
# test cost:  0.027088931854814292 test accuracy:  0.025999999418854714
# Next_Train----------: step =  150
# train_cost:  0.01439542593434453 train_accuracy:  0.014999999664723873
# test cost:  0.026367912627756597 test accuracy:  0.006999999843537807
# Next_Train----------: step =  200
# train_cost:  0.013374704215675593 train_accuracy:  0.017999999597668646
# test cost:  0.027271727472543715 test accuracy:  0.009999999776482582
# Next_Train----------: step =  250
# train_cost:  0.011393012199550866 train_accuracy:  0.018999999575316905
# test cost:  0.028200218547135593 test accuracy:  0.019999999552965164
# Next_Train----------: step =  300
# train_cost:  0.01079848138615489 train_accuracy:  0.026999999396502973
# test cost:  0.027389906998723745 test accuracy:  0.010999999754130841
# Next_Train----------: step =  350
# train_cost:  0.009628815646283328 train_accuracy:  0.02799999937415123
# test cost:  0.028473770432174205 test accuracy:  0.022999999485909937
# Next_Train----------: step =  400
# train_cost:  0.008221516036428511 train_accuracy:  0.014999999664723873
# test cost:  0.028115761559456588 test accuracy:  0.01699999962002039
# Next_Train----------: step =  450
# train_cost:  0.007192284055054188 train_accuracy:  0.020999999530613423
# test cost:  0.02760890666395426 test accuracy:  0.014999999664723873
# Next_Train----------: step =  500
# train_cost:  0.0074999842559918765 train_accuracy:  0.03499999921768904
# test cost:  0.027484198240563272 test accuracy:  0.018999999575316905
# Next_Train----------: step =  550
# train_cost:  0.007362719834782183 train_accuracy:  0.017999999597668646
# test cost:  0.0280724145937711 test accuracy:  0.015999999642372132
# Next_Train----------: step =  600
# train_cost:  0.006415458186529577 train_accuracy:  0.022999999485909937
# test cost:  0.028474034648388623 test accuracy:  0.017999999597668646
# Next_Train----------: step =  650
# train_cost:  0.005799544928595424 train_accuracy:  0.02799999937415123
# test cost:  0.028012787783518435 test accuracy:  0.013999999687075614
# Next_Train----------: step =  700
# train_cost:  0.005151747423224151 train_accuracy:  0.031999999284744264
# test cost:  0.028118371358141304 test accuracy:  0.01699999962002039
# Next_Train----------: step =  750
# train_cost:  0.004750282852910459 train_accuracy:  0.023999999463558196
# test cost:  0.02873230166733265 test accuracy:  0.017999999597668646
# Next_Train----------: step =  800
# train_cost:  0.0040943784639239315 train_accuracy:  0.025999999418854714
# test cost:  0.028540806937962772 test accuracy:  0.012999999709427357
# Next_Train----------: step =  850
# train_cost:  0.003646209929138422 train_accuracy:  0.03499999921768904
# test cost:  0.02958579212427139 test accuracy:  0.020999999530613423
# Next_Train----------: step =  900
# train_cost:  0.0038432198110967875 train_accuracy:  0.025999999418854714
# test cost:  0.029847293719649316 test accuracy:  0.01699999962002039
# Next_Train----------: step =  950
# train_cost:  0.0030524623463861643 train_accuracy:  0.10899999998509884
# test cost:  0.028805202711373566 test accuracy:  0.050999999046325684
# Next_Train----------: step =  1000
# train_cost:  0.002842779824277386 train_accuracy:  0.03399999924004078
# test cost:  0.028238848596811295 test accuracy:  0.020999999530613423
# Next_Train----------: step =  1050
# train_cost:  0.0024406219366937877 train_accuracy:  0.03399999942630529
# test cost:  0.02877436960116029 test accuracy:  0.015999999642372132
# Next_Train----------: step =  1100
# train_cost:  0.0023170793137978762 train_accuracy:  0.03599999919533729
# test cost:  0.028917601332068443 test accuracy:  0.017999999597668646
# Next_Train----------: step =  1150
# train_cost:  0.002384373964741826 train_accuracy:  0.03299999926239252
# test cost:  0.029172530956566335 test accuracy:  0.017999999597668646
# Next_Train----------: step =  1200
# train_cost:  0.0022721713117789476 train_accuracy:  0.03799999915063381
# test cost:  0.029380358243361115 test accuracy:  0.018999999575316905
# Next_Train----------: step =  1250
# train_cost:  0.002363704715389758 train_accuracy:  0.044999999552965166
# test cost:  0.02942096758633852 test accuracy:  0.03499999921768904
# Next_Train----------: step =  1300
# train_cost:  0.0024645246856380256 train_accuracy:  0.026999999582767487
# test cost:  0.029158141743391753 test accuracy:  0.017999999597668646
# Next_Train----------: step =  1350
# train_cost:  0.00242387363105081 train_accuracy:  0.028999999351799487
# test cost:  0.02874487778171897 test accuracy:  0.023999999463558196
# Next_Train----------: step =  1400
# train_cost:  0.0026787707407493143 train_accuracy:  0.04999999925494194
# test cost:  0.028831809759140015 test accuracy:  0.02799999937415123
# Next_Train----------: step =  1450
# train_cost:  0.0023591502220369877 train_accuracy:  0.04399999938905239
# test cost:  0.029035399574786423 test accuracy:  0.024999999441206455
# Next_Train----------: step =  1500
# train_cost:  0.002437885740073398 train_accuracy:  0.03099999949336052
# test cost:  0.028720039641484618 test accuracy:  0.017999999597668646
# Next_Train----------: step =  1550
# train_cost:  0.0024495680700056255 train_accuracy:  0.026999999396502973
# test cost:  0.029191492591053247 test accuracy:  0.022999999485909937
# Next_Train----------: step =  1600
# train_cost:  0.0024521753075532615 train_accuracy:  0.0389999995008111
# test cost:  0.0293359050527215 test accuracy:  0.01699999962002039
# Next_Train----------: step =  1650
# train_cost:  0.002135047595947981 train_accuracy:  0.03599999956786633
# test cost:  0.029945281613618136 test accuracy:  0.024999999441206455
# Next_Train----------: step =  1700
# train_cost:  0.00227122925571166 train_accuracy:  0.043999999016523364
# test cost:  0.029934555012732744 test accuracy:  0.022999999485909937
# Next_Train----------: step =  1750
# train_cost:  0.0021106676605995743 train_accuracy:  0.06199999935925007
# test cost:  0.029026890732347967 test accuracy:  0.028999999538064
# Next_Train----------: step =  1800
# train_cost:  0.002083084254991263 train_accuracy:  0.04499999936670065
# test cost:  0.029195305379107594 test accuracy:  0.01699999962002039
# Next_Train----------: step =  1850
# train_cost:  0.0018360864458372816 train_accuracy:  0.03599999919533729
# test cost:  0.0296204952057451 test accuracy:  0.022999999485909937
# Next_Train----------: step =  1900
# train_cost:  0.0017566226015333086 train_accuracy:  0.03799999933689833
# test cost:  0.029531855741515754 test accuracy:  0.018999999575316905
# Next_Train----------: step =  1950
# train_cost:  0.0017118920222856104 train_accuracy:  0.03399999924004078
# test cost:  0.02924613291397691 test accuracy:  0.020999999530613423
# Next_Train----------: step =  2000
# train_cost:  0.0018145100388210268 train_accuracy:  0.0409999992698431
# test cost:  0.02989423512481153 test accuracy:  0.02499999962747097
# Next_Train----------: step =  2050
# train_cost:  0.0021878800005652012 train_accuracy:  0.044999999552965166
# test cost:  0.0298962383531034 test accuracy:  0.026999999582767487
# Next_Train----------: step =  2100
# train_cost:  0.0023176644870545717 train_accuracy:  0.03599999975413084
# test cost:  0.0294440811034292 test accuracy:  0.01699999962002039
# Next_Train----------: step =  2150
# train_cost:  0.001887679917854257 train_accuracy:  0.04599999953061342
# test cost:  0.02914281003177166 test accuracy:  0.02799999974668026
# Next_Train----------: step =  2200
# train_cost:  0.001998200817615725 train_accuracy:  0.03599999956786633
# test cost:  0.029297230206429957 test accuracy:  0.021999999508261682
# Next_Train----------: step =  2250
# train_cost:  0.0020728808303829283 train_accuracy:  0.034999999403953555
# test cost:  0.02965377359651029 test accuracy:  0.025999999418854714
# Next_Train----------: step =  2300
# train_cost:  0.002115165174473077 train_accuracy:  0.03999999947845936
# test cost:  0.02923908652737737 test accuracy:  0.015999999642372132
# Next_Train----------: step =  2350
# train_cost:  0.0016207935550482944 train_accuracy:  0.041999999433755875
# test cost:  0.02928532101213932 test accuracy:  0.029999999701976775
# Next_Train----------: step =  2400
# train_cost:  0.001538494773558341 train_accuracy:  0.05299999937415123
# test cost:  0.029327283008024098 test accuracy:  0.03299999926239252
# Next_Train----------: step =  2450
# train_cost:  0.0012368862866424025 train_accuracy:  0.03799999933689833
# test cost:  0.029395747976377607 test accuracy:  0.02399999964982271
# Next_Train----------: step =  2500
# train_cost:  0.0011248396069277078 train_accuracy:  0.03599999956786633
# test cost:  0.02931982115842402 test accuracy:  0.017999999783933164
# Next_Train----------: step =  2550
# train_cost:  0.0010885777010116726 train_accuracy:  0.055999999307096
# test cost:  0.02942826636135578 test accuracy:  0.026999999582767487
# Next_Train----------: step =  2600
# train_cost:  0.001189966915990226 train_accuracy:  0.053999999165534975
# test cost:  0.029565861308947207 test accuracy:  0.02399999964982271
# Next_Train----------: step =  2650
# train_cost:  0.0012978388462215663 train_accuracy:  0.03899999912828207
# test cost:  0.029680290212854742 test accuracy:  0.031999999471008775
# Next_Train----------: step =  2700
# train_cost:  0.0012975506455404685 train_accuracy:  0.04999999888241291
# test cost:  0.029389516357332467 test accuracy:  0.017999999597668646
# Next_Train----------: step =  2750
# train_cost:  0.0013670885440660641 train_accuracy:  0.05499999914318323
# test cost:  0.029585505649447442 test accuracy:  0.029999999329447746
# Next_Train----------: step =  2800
# train_cost:  0.0014269414736190812 train_accuracy:  0.04299999922513962
# test cost:  0.029831415275111794 test accuracy:  0.028999999351799487
# Next_Train----------: step =  2850
# train_cost:  0.0016326820710673927 train_accuracy:  0.03599999938160181
# test cost:  0.02959248498082161 test accuracy:  0.02499999962747097
# Next_Train----------: step =  2900
# train_cost:  0.0017727081140037626 train_accuracy:  0.02599999960511923
# test cost:  0.03002618011087179 test accuracy:  0.018999999575316905
# Next_Train----------: step =  2950
# train_cost:  0.0018641313508851454 train_accuracy:  0.03599999919533729
# test cost:  0.029695482179522514 test accuracy:  0.029999999701976775
# Next_Train----------: step =  3000
# train_cost:  0.0019409731350606308 train_accuracy:  0.048999998904764655
# test cost:  0.029630921641364695 test accuracy:  0.024999999441206455
# Next_Train----------: step =  3050
# train_cost:  0.001706932796514593 train_accuracy:  0.03299999944865704
# test cost:  0.03047201344743371 test accuracy:  0.019999999552965164
# Next_Train----------: step =  3100
# train_cost:  0.0020292579516535624 train_accuracy:  0.038999999314546584
# test cost:  0.030662662396207453 test accuracy:  0.019999999552965164
# Next_Train----------: step =  3150
# train_cost:  0.0019694834016263487 train_accuracy:  0.06400000005960464
# test cost:  0.029421233013272284 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3200
# train_cost:  0.002266017851070501 train_accuracy:  0.046999999321997166
# test cost:  0.029159146128222346 test accuracy:  0.021999999508261682
# Next_Train----------: step =  3250
# train_cost:  0.001640526982373558 train_accuracy:  0.041999999061226846
# test cost:  0.02976177278906107 test accuracy:  0.019999999552965164
# Next_Train----------: step =  3300
# train_cost:  0.0017478405381552875 train_accuracy:  0.03999999910593033
# test cost:  0.030305688595399262 test accuracy:  0.020999999716877937
# Next_Train----------: step =  3350
# train_cost:  0.0015913468931103125 train_accuracy:  0.04299999959766865
# test cost:  0.029835212510079145 test accuracy:  0.019999999552965164
# Next_Train----------: step =  3400
# train_cost:  0.0016165370441740378 train_accuracy:  0.03599999919533729
# test cost:  0.0290794656611979 test accuracy:  0.014999999664723873
# Next_Train----------: step =  3450
# train_cost:  0.0014467558037722483 train_accuracy:  0.0409999992698431
# test cost:  0.029533692728728057 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3500
# train_cost:  0.0014130642201052978 train_accuracy:  0.041999999433755875
# test cost:  0.030007063038647176 test accuracy:  0.014999999664723873
# Next_Train----------: step =  3550
# train_cost:  0.0015197989356238394 train_accuracy:  0.03599999919533729
# test cost:  0.030355237424373627 test accuracy:  0.021999999508261682
# Next_Train----------: step =  3600
# train_cost:  0.0014166537235723808 train_accuracy:  0.04699999894946814
# test cost:  0.030101491464301945 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3650
# train_cost:  0.0013904148450819775 train_accuracy:  0.04599999934434891
# test cost:  0.03003433858975768 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3700
# train_cost:  0.0014698014099849388 train_accuracy:  0.03199999965727329
# test cost:  0.029838997311890124 test accuracy:  0.016999999806284905
# Next_Train----------: step =  3750
# train_cost:  0.0014591713057598098 train_accuracy:  0.03599999975413084
# test cost:  0.02944790944457054 test accuracy:  0.01699999962002039
# Next_Train----------: step =  3800
# train_cost:  0.0015473927080165595 train_accuracy:  0.02799999937415123
# test cost:  0.030135421128943563 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3850
# train_cost:  0.0016375659586628899 train_accuracy:  0.034999999590218066
# test cost:  0.030600201850757004 test accuracy:  0.013999999687075614
# Next_Train----------: step =  3900
# train_cost:  0.0015523628768278285 train_accuracy:  0.046999999321997166
# test cost:  0.030651832139119504 test accuracy:  0.019999999552965164
# Next_Train----------: step =  3950
# train_cost:  0.001461308979196474 train_accuracy:  0.06799999885261059
# test cost:  0.030546375177800657 test accuracy:  0.018999999575316905
# Next_Train----------: step =  4000
# train_cost:  0.0015280069230357185 train_accuracy:  0.029999999329447746
# test cost:  0.030011242255568504 test accuracy:  0.012999999709427357
# Next_Train----------: step =  4050
# train_cost:  0.0018123032845323906 train_accuracy:  0.04299999922513962
# test cost:  0.030462057422846557 test accuracy:  0.015999999642372132
# Next_Train----------: step =  4100
# train_cost:  0.0015280512161552906 train_accuracy:  0.04999999925494194
# test cost:  0.030461129872128366 test accuracy:  0.025999999418854714
# Next_Train----------: step =  4150
# train_cost:  0.0014367562835104764 train_accuracy:  0.0679999990388751
# test cost:  0.030277498345822097 test accuracy:  0.026999999396502973
# Next_Train----------: step =  4200
# train_cost:  0.0013512933248421178 train_accuracy:  0.031999999284744264
# test cost:  0.029556747060269117 test accuracy:  0.011999999731779098
# Next_Train----------: step =  4250
# train_cost:  0.0011035905685275794 train_accuracy:  0.039999999292194846
# test cost:  0.029946345183998347 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4300
# train_cost:  0.001069723692489788 train_accuracy:  0.041999999061226846
# test cost:  0.030201055621728302 test accuracy:  0.018999999575316905
# Next_Train----------: step =  4350
# train_cost:  0.0010581144917523489 train_accuracy:  0.048999999277293683
# test cost:  0.029824617598205806 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4400
# train_cost:  0.0010740175610408186 train_accuracy:  0.0529999990016222
# test cost:  0.03001434961333871 test accuracy:  0.021999999508261682
# Next_Train----------: step =  4450
# train_cost:  0.001041230790724512 train_accuracy:  0.041999999433755875
# test cost:  0.03002727562561631 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4500
# train_cost:  0.001067288916965481 train_accuracy:  0.05499999932944775
# test cost:  0.03017629636451602 test accuracy:  0.013999999687075614
# Next_Train----------: step =  4550
# train_cost:  0.001172198378480971 train_accuracy:  0.04999999906867743
# test cost:  0.029878728557378054 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4600
# train_cost:  0.0012160554557340219 train_accuracy:  0.05299999937415123
# test cost:  0.03002729923464358 test accuracy:  0.02599999960511923
# Next_Train----------: step =  4650
# train_cost:  0.0011787290481152014 train_accuracy:  0.045999998971819875
# test cost:  0.03014726135879755 test accuracy:  0.023999999463558196
# Next_Train----------: step =  4700
# train_cost:  0.0012179340526927262 train_accuracy:  0.04499999918043614
# test cost:  0.03050639256834984 test accuracy:  0.017999999597668646
# Next_Train----------: step =  4750
# train_cost:  0.0012613763858098537 train_accuracy:  0.05499999932944775
# test cost:  0.030385503824800254 test accuracy:  0.022999999485909937
# Next_Train----------: step =  4800
# train_cost:  0.001372215290029999 train_accuracy:  0.036999999545514584
# test cost:  0.030478611309081315 test accuracy:  0.017999999597668646
# Next_Train----------: step =  4850
# train_cost:  0.001708166382741183 train_accuracy:  0.0429999990388751
# test cost:  0.030217316560447217 test accuracy:  0.012999999709427357
# Next_Train----------: step =  4900
# train_cost:  0.0016897721594432368 train_accuracy:  0.031999999284744264
# test cost:  0.03000286906026304 test accuracy:  0.013999999687075614
# Next_Train----------: step =  4950
# train_cost:  0.0019281701563159004 train_accuracy:  0.046999999694526194
# test cost:  0.0298548333812505 test accuracy:  0.022999999485909937
# Next_Train----------: step =  5000
# train_cost:  0.0017495818698080256 train_accuracy:  0.04299999941140413
# test cost:  0.030454652896150947 test accuracy:  0.021999999508261682
