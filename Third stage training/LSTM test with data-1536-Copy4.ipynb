# %% [markdown]
# # Simple RNN test by data-3*512
# # 5000 steps with lr = 0.001

# %% [markdown]
# Results are better than
# best run:

# %%
import numpy as np

np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import SimpleRNN, Activation, Dense, Flatten,LSTM, TimeDistributed
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.optimizers import RMSprop

TIME_STEPS = 3
INPUT_SIZE = 512
BATCH_SIZE = 50
BATCH_INDEX = 0
OUTPUT_SIZE = 1536
#CELL_SIZE = 800
LR = 0.001


           
           
# loading data
X_train = np.loadtxt("0126_spec_train_1000.txt")
y_train = np.loadtxt("0126_mask_train_1000.txt")

X_test = np.loadtxt("0126_spec_test_1000.txt")
y_test = np.loadtxt("0126_mask_test_1000.txt")

# batch_size=y_test.shape[0]

# data pre-processing
X_train = X_train.reshape(-1, 3, 512)
#y_train = y_train.reshape(-1, 3, 512)
X_test = X_test.reshape(-1, 3, 512)
#y_test = y_test.reshape(-1, 3, 512)

#  build RNN model
model = Sequential()

# RNN cell

model.add(LSTM(
    units =500,
    batch_input_shape=( BATCH_SIZE, TIME_STEPS, INPUT_SIZE),
    #input_dim=INPUT_SIZE,
    #input_length=TIME_STEPS,
    #output_dim=CELL_SIZE,
    #return_sequences=True,
    #stateful=True 
    unroll=True
))

# output layer
#model.add(Flatten())
model.add((Dense(OUTPUT_SIZE)))  #TimeDistributed
#model.add(Activation('hard_sigmoid'))

# # optimizer
#
adam = Adam(LR)

#optimizer
#rmsprop = RMSprop(lr=0.0001, rho=0.9, epsilon=1e-8, decay=0.0)

model.compile(optimizer=adam,
              loss='mse',
              metrics=['accuracy'])

# # training
#

for step in range(5001):
    # data shape = (batch_num, steps, inputs/outputs)
    X_batch = X_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :, :]
    Y_batch = y_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :]
    cost = model.train_on_batch(X_batch, Y_batch)
    BATCH_INDEX += BATCH_SIZE
    BATCH_INDEX = 0 if BATCH_INDEX >= X_train.shape[0] else BATCH_INDEX

    if step % 50 == 0:
        print('Next_Train----------: step = ', step)
        train_cost, train_accuracy = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=False)
        print('train_cost: ', train_cost, 'train_accuracy: ', train_accuracy)
        cost, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=False)
        print('test cost: ', cost, 'test accuracy: ', accuracy)
        
       

# print('Train-------------------------')
#
# history = model.fit(X_train, y_train, validation_split=0.25, epochs=3100, shuffle=True, batch_size=75, verbose=1)
#
# # Plot training & validation accuracy values
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# # Plot training & validation loss values
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# get_3rd_layer_output = K.function([model.layers[0].input],
#                                   [model.layers[1].output])
# layer_output1 = get_3rd_layer_output([X_train])[0]
#
# print(layer_output1)
# Out:
# /home/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Next_Train----------: step =  0
# train_cost:  0.03716519000008702 train_accuracy:  0.0
# test cost:  0.0449407834559679 test accuracy:  0.0009999999776482583
# Next_Train----------: step =  50
# train_cost:  0.02315896237269044 train_accuracy:  0.020999999530613423
# test cost:  0.0300736740231514 test accuracy:  0.010999999754130841
# Next_Train----------: step =  100
# train_cost:  0.02000526445917785 train_accuracy:  0.01699999962002039
# test cost:  0.02757354243658483 test accuracy:  0.008999999798834323
# Next_Train----------: step =  150
# train_cost:  0.018155146529898046 train_accuracy:  0.011999999731779098
# test cost:  0.026923414366319776 test accuracy:  0.006999999843537807
# Next_Train----------: step =  200
# train_cost:  0.017029751418158413 train_accuracy:  0.022999999485909937
# test cost:  0.026264403900131583 test accuracy:  0.012999999709427357
# Next_Train----------: step =  250
# train_cost:  0.01551302457228303 train_accuracy:  0.024999999441206455
# test cost:  0.02600115854293108 test accuracy:  0.023999999463558196
# Next_Train----------: step =  300
# train_cost:  0.014864421635866164 train_accuracy:  0.020999999530613423
# test cost:  0.025732191931456327 test accuracy:  0.01699999962002039
# Next_Train----------: step =  350
# train_cost:  0.01441504480317235 train_accuracy:  0.031999999471008775
# test cost:  0.026382800284773113 test accuracy:  0.014999999664723873
# Next_Train----------: step =  400
# train_cost:  0.013266798737458885 train_accuracy:  0.02599999960511923
# test cost:  0.025596807105466725 test accuracy:  0.021999999694526196
# Next_Train----------: step =  450
# train_cost:  0.012385849887505174 train_accuracy:  0.025999999418854714
# test cost:  0.025481654703617095 test accuracy:  0.021999999508261682
# Next_Train----------: step =  500
# train_cost:  0.011866882303729653 train_accuracy:  0.028999999538064
# test cost:  0.025558641599491238 test accuracy:  0.022999999672174455
# Next_Train----------: step =  550
# train_cost:  0.011069779517129064 train_accuracy:  0.03299999926239252
# test cost:  0.025501651875674724 test accuracy:  0.03399999979883432
# Next_Train----------: step =  600
# train_cost:  0.010344248195178807 train_accuracy:  0.03299999926239252
# test cost:  0.025703267008066178 test accuracy:  0.019999999552965164
# Next_Train----------: step =  650
# train_cost:  0.00983501193113625 train_accuracy:  0.031999999284744264
# test cost:  0.025637353025376796 test accuracy:  0.028999999351799487
# Next_Train----------: step =  700
# train_cost:  0.00932293974328786 train_accuracy:  0.03399999924004078
# test cost:  0.02594565153121948 test accuracy:  0.020999999530613423
# Next_Train----------: step =  750
# train_cost:  0.008924769959412516 train_accuracy:  0.026999999396502973
# test cost:  0.026194881135597824 test accuracy:  0.02499999962747097
# Next_Train----------: step =  800
# train_cost:  0.00862705463077873 train_accuracy:  0.030999999307096005
# test cost:  0.026399552868679167 test accuracy:  0.021999999694526196
# Next_Train----------: step =  850
# train_cost:  0.00833320040255785 train_accuracy:  0.023999999463558196
# test cost:  0.026301465323194863 test accuracy:  0.025999999418854714
# Next_Train----------: step =  900
# train_cost:  0.008302970230579377 train_accuracy:  0.029999999329447746
# test cost:  0.026744980504736303 test accuracy:  0.019999999552965164
# Next_Train----------: step =  950
# train_cost:  0.007721644314005971 train_accuracy:  0.02799999937415123
# test cost:  0.026961581036448478 test accuracy:  0.027999999560415746
# Next_Train----------: step =  1000
# train_cost:  0.0075361153576523066 train_accuracy:  0.030999999307096005
# test cost:  0.027196407970041036 test accuracy:  0.022999999672174455
# Next_Train----------: step =  1050
# train_cost:  0.007110033836215735 train_accuracy:  0.029999999329447746
# test cost:  0.027113332785665988 test accuracy:  0.02499999962747097
# Next_Train----------: step =  1100
# train_cost:  0.007193466951139271 train_accuracy:  0.03299999926239252
# test cost:  0.02726254048757255 test accuracy:  0.022999999485909937
# Next_Train----------: step =  1150
# train_cost:  0.006633529299870133 train_accuracy:  0.028999999351799487
# test cost:  0.027218369394540788 test accuracy:  0.02399999964982271
# Next_Train----------: step =  1200
# train_cost:  0.006351361400447786 train_accuracy:  0.03399999942630529
# test cost:  0.027904538344591855 test accuracy:  0.028999999351799487
# Next_Train----------: step =  1250
# train_cost:  0.005921163875609636 train_accuracy:  0.028999999351799487
# test cost:  0.02780183553695679 test accuracy:  0.023999999463558196
# Next_Train----------: step =  1300
# train_cost:  0.005865134228952229 train_accuracy:  0.026999999582767487
# test cost:  0.028357421234250068 test accuracy:  0.02399999964982271
# Next_Train----------: step =  1350
# train_cost:  0.005503165489062667 train_accuracy:  0.03099999949336052
# test cost:  0.02837046654894948 test accuracy:  0.029999999701976775
# Next_Train----------: step =  1400
# train_cost:  0.005671422136947513 train_accuracy:  0.02799999937415123
# test cost:  0.0282928004860878 test accuracy:  0.028999999351799487
# Next_Train----------: step =  1450
# train_cost:  0.005151095462497324 train_accuracy:  0.031999999284744264
# test cost:  0.028387099876999854 test accuracy:  0.028999999538064
# Next_Train----------: step =  1500
# train_cost:  0.005453939677681774 train_accuracy:  0.034999999403953555
# test cost:  0.029728081170469524 test accuracy:  0.02399999964982271
# Next_Train----------: step =  1550
# train_cost:  0.0056065043667331334 train_accuracy:  0.027999999560415746
# test cost:  0.02874167375266552 test accuracy:  0.02399999964982271
# Next_Train----------: step =  1600
# train_cost:  0.0059305763803422454 train_accuracy:  0.031999999471008775
# test cost:  0.028307063225656747 test accuracy:  0.019999999552965164
# Next_Train----------: step =  1650
# train_cost:  0.005241087067406625 train_accuracy:  0.034999999403953555
# test cost:  0.02941073877736926 test accuracy:  0.023999999463558196
# Next_Train----------: step =  1700
# train_cost:  0.004697492171544582 train_accuracy:  0.028999999351799487
# test cost:  0.029523681197315455 test accuracy:  0.02399999964982271
# Next_Train----------: step =  1750
# train_cost:  0.004294218320865184 train_accuracy:  0.03299999944865704
# test cost:  0.02946699010208249 test accuracy:  0.02999999951571226
# Next_Train----------: step =  1800
# train_cost:  0.004434391518589109 train_accuracy:  0.029999999329447746
# test cost:  0.028962426446378232 test accuracy:  0.021999999508261682
# Next_Train----------: step =  1850
# train_cost:  0.0042100262013264 train_accuracy:  0.027999999560415746
# test cost:  0.0290904282592237 test accuracy:  0.02399999964982271
# Next_Train----------: step =  1900
# train_cost:  0.004271590802818537 train_accuracy:  0.030999999307096005
# test cost:  0.029653540812432766 test accuracy:  0.028999999351799487
# Next_Train----------: step =  1950
# train_cost:  0.004141786484979093 train_accuracy:  0.03099999949336052
# test cost:  0.030037855450063943 test accuracy:  0.03099999949336052
# Next_Train----------: step =  2000
# train_cost:  0.004284390190150589 train_accuracy:  0.031999999284744264
# test cost:  0.03088282309472561 test accuracy:  0.02899999972432852
# Next_Train----------: step =  2050
# train_cost:  0.003797358518932015 train_accuracy:  0.03399999961256981
# test cost:  0.02973990486934781 test accuracy:  0.03099999949336052
# Next_Train----------: step =  2100
# train_cost:  0.0038116198615171016 train_accuracy:  0.029999999329447746
# test cost:  0.029961496777832507 test accuracy:  0.031999999471008775
# Next_Train----------: step =  2150
# train_cost:  0.003408376849256456 train_accuracy:  0.03299999944865704
# test cost:  0.029934804979711772 test accuracy:  0.028999999351799487
# Next_Train----------: step =  2200
# train_cost:  0.0035037292749620975 train_accuracy:  0.030999999679625034
# test cost:  0.030087210517376662 test accuracy:  0.027999999560415746
# Next_Train----------: step =  2250
# train_cost:  0.0031761855934746563 train_accuracy:  0.036999999545514584
# test cost:  0.03027832619845867 test accuracy:  0.03299999944865704
# Next_Train----------: step =  2300
# train_cost:  0.0031293221632950007 train_accuracy:  0.03399999942630529
# test cost:  0.030349614191800357 test accuracy:  0.026999999396502973
# Next_Train----------: step =  2350
# train_cost:  0.0029466105508618055 train_accuracy:  0.03399999942630529
# test cost:  0.030627782829105853 test accuracy:  0.025999999418854714
# Next_Train----------: step =  2400
# train_cost:  0.0030953328241594136 train_accuracy:  0.03299999944865704
# test cost:  0.0303669354878366 test accuracy:  0.02799999937415123
# Next_Train----------: step =  2450
# train_cost:  0.0031404346926137807 train_accuracy:  0.030999999679625034
# test cost:  0.030771697871387005 test accuracy:  0.020999999530613423
# Next_Train----------: step =  2500
# train_cost:  0.003301445464603603 train_accuracy:  0.03499999921768904
# test cost:  0.03143582129850984 test accuracy:  0.02799999937415123
# Next_Train----------: step =  2550
# train_cost:  0.002920513320714235 train_accuracy:  0.03299999926239252
# test cost:  0.03066137544810772 test accuracy:  0.03399999924004078
# Next_Train----------: step =  2600
# train_cost:  0.002960360352881253 train_accuracy:  0.034999999590218066
# test cost:  0.031022959761321543 test accuracy:  0.024999999441206455
# Next_Train----------: step =  2650
# train_cost:  0.0027914187056012453 train_accuracy:  0.03299999944865704
# test cost:  0.03076817896217108 test accuracy:  0.02999999951571226
# Next_Train----------: step =  2700
# train_cost:  0.0027212293760385366 train_accuracy:  0.04199999962002039
# test cost:  0.030765210464596748 test accuracy:  0.029999999329447746
# Next_Train----------: step =  2750
# train_cost:  0.002502702549099922 train_accuracy:  0.031999999284744264
# test cost:  0.031033742893487214 test accuracy:  0.031999999471008775
# Next_Train----------: step =  2800
# train_cost:  0.0026874695671722294 train_accuracy:  0.03399999942630529
# test cost:  0.030550393648445605 test accuracy:  0.022999999485909937
# Next_Train----------: step =  2850
# train_cost:  0.002550728968344629 train_accuracy:  0.030999999307096005
# test cost:  0.03110851515084505 test accuracy:  0.028999999538064
# Next_Train----------: step =  2900
# train_cost:  0.0029009205754846334 train_accuracy:  0.036999999359250066
# test cost:  0.032014021556824444 test accuracy:  0.02799999937415123
# Next_Train----------: step =  2950
# train_cost:  0.0025705813837703317 train_accuracy:  0.036999999545514584
# test cost:  0.031000602617859842 test accuracy:  0.02899999972432852
# Next_Train----------: step =  3000
# train_cost:  0.0024845320382155477 train_accuracy:  0.03799999952316284
# test cost:  0.03039701860398054 test accuracy:  0.028999999538064
# Next_Train----------: step =  3050
# train_cost:  0.0022721146349795164 train_accuracy:  0.03899999912828207
# test cost:  0.031168962456285955 test accuracy:  0.028999999351799487
# Next_Train----------: step =  3100
# train_cost:  0.0029391269257757814 train_accuracy:  0.03599999919533729
# test cost:  0.03244417570531368 test accuracy:  0.03299999944865704
# Next_Train----------: step =  3150
# train_cost:  0.0025075649260543286 train_accuracy:  0.043999999202787875
# test cost:  0.032239016983658074 test accuracy:  0.034999999776482583
# Next_Train----------: step =  3200
# train_cost:  0.0023947532230522484 train_accuracy:  0.031999999471008775
# test cost:  0.031216321233659982 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3250
# train_cost:  0.002138087264029309 train_accuracy:  0.04299999941140413
# test cost:  0.030729512684047222 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3300
# train_cost:  0.001962254219688475 train_accuracy:  0.039999999664723875
# test cost:  0.03092418434098363 test accuracy:  0.026999999582767487
# Next_Train----------: step =  3350
# train_cost:  0.0017832876765169203 train_accuracy:  0.03999999910593033
# test cost:  0.03138768710196018 test accuracy:  0.02999999951571226
# Next_Train----------: step =  3400
# train_cost:  0.001785110222408548 train_accuracy:  0.03599999975413084
# test cost:  0.03173714699223638 test accuracy:  0.029999999329447746
# Next_Train----------: step =  3450
# train_cost:  0.0017099906457588077 train_accuracy:  0.039999999292194846
# test cost:  0.03159682303667068 test accuracy:  0.03299999944865704
# Next_Train----------: step =  3500
# train_cost:  0.0017891026334837079 train_accuracy:  0.0409999992698431
# test cost:  0.03149262499064207 test accuracy:  0.026999999396502973
# Next_Train----------: step =  3550
# train_cost:  0.0018182213243562728 train_accuracy:  0.03299999944865704
# test cost:  0.031521801743656395 test accuracy:  0.02599999960511923
# Next_Train----------: step =  3600
# train_cost:  0.0018242785648908467 train_accuracy:  0.03599999938160181
# test cost:  0.03161978246644139 test accuracy:  0.025999999418854714
# Next_Train----------: step =  3650
# train_cost:  0.001764052116777748 train_accuracy:  0.03299999944865704
# test cost:  0.03202281063422561 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3700
# train_cost:  0.002151020773453638 train_accuracy:  0.034999999403953555
# test cost:  0.03279429404065013 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3750
# train_cost:  0.0018446896923705936 train_accuracy:  0.04199999924749136
# test cost:  0.032236424088478086 test accuracy:  0.028999999538064
# Next_Train----------: step =  3800
# train_cost:  0.0018730604148004203 train_accuracy:  0.042999999783933165
# test cost:  0.03128105700016022 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3850
# train_cost:  0.0016480901278555394 train_accuracy:  0.034999999403953555
# test cost:  0.03133042091503739 test accuracy:  0.019999999552965164
# Next_Train----------: step =  3900
# train_cost:  0.002011826355010271 train_accuracy:  0.039999999292194846
# test cost:  0.032949211448431014 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3950
# train_cost:  0.001921393518568948 train_accuracy:  0.051999999396502974
# test cost:  0.032927957363426685 test accuracy:  0.024999999441206455
# Next_Train----------: step =  4000
# train_cost:  0.001946319843409583 train_accuracy:  0.048999999277293683
# test cost:  0.03220933750271797 test accuracy:  0.022999999485909937
# Next_Train----------: step =  4050
# train_cost:  0.001880194852128625 train_accuracy:  0.04299999941140413
# test cost:  0.03134356774389744 test accuracy:  0.020999999530613423
# Next_Train----------: step =  4100
# train_cost:  0.001749042671872303 train_accuracy:  0.04799999948590994
# test cost:  0.030898493248969316 test accuracy:  0.02599999960511923
# Next_Train----------: step =  4150
# train_cost:  0.0014517639530822635 train_accuracy:  0.039999999292194846
# test cost:  0.03134051002562046 test accuracy:  0.022999999485909937
# Next_Train----------: step =  4200
# train_cost:  0.0015665210812585428 train_accuracy:  0.038999999314546584
# test cost:  0.03212659377604723 test accuracy:  0.022999999672174455
# Next_Train----------: step =  4250
# train_cost:  0.0014655924926046282 train_accuracy:  0.056999999284744265
# test cost:  0.032602629996836184 test accuracy:  0.025999999791383743
# Next_Train----------: step =  4300
# train_cost:  0.0015233636513585225 train_accuracy:  0.04299999941140413
# test cost:  0.033033364452421665 test accuracy:  0.020999999716877937
# Next_Train----------: step =  4350
# train_cost:  0.0013958947616629302 train_accuracy:  0.04299999959766865
# test cost:  0.03228519335389137 test accuracy:  0.022999999672174455
# Next_Train----------: step =  4400
# train_cost:  0.0014438902609981597 train_accuracy:  0.056999999284744265
# test cost:  0.031763423886150124 test accuracy:  0.022999999672174455
# Next_Train----------: step =  4450
# train_cost:  0.0013546783477067948 train_accuracy:  0.04999999925494194
# test cost:  0.03174171606078744 test accuracy:  0.02399999964982271
# Next_Train----------: step =  4500
# train_cost:  0.0013110312342178077 train_accuracy:  0.042999999783933165
# test cost:  0.03177783256396651 test accuracy:  0.021999999694526196
# Next_Train----------: step =  4550
# train_cost:  0.0013137618458131327 train_accuracy:  0.0549999987706542
# test cost:  0.032311301585286854 test accuracy:  0.026999999769032
# Next_Train----------: step =  4600
# train_cost:  0.0014911385835148395 train_accuracy:  0.05099999960511923
# test cost:  0.0330038876272738 test accuracy:  0.022999999672174455
# Next_Train----------: step =  4650
# train_cost:  0.001429453244782053 train_accuracy:  0.050999999046325684
# test cost:  0.032338881958276035 test accuracy:  0.021999999694526196
# Next_Train----------: step =  4700
# train_cost:  0.0012614918639883399 train_accuracy:  0.051999999582767485
# test cost:  0.03236403902992606 test accuracy:  0.020999999716877937
# Next_Train----------: step =  4750
# train_cost:  0.0012683849898166954 train_accuracy:  0.05799999926239252
# test cost:  0.03194364393129945 test accuracy:  0.02599999960511923
# Next_Train----------: step =  4800
# train_cost:  0.0014011788502102719 train_accuracy:  0.05499999895691872
# test cost:  0.03147323783487081 test accuracy:  0.02399999964982271
# Next_Train----------: step =  4850
# train_cost:  0.0012593858758918942 train_accuracy:  0.03999999910593033
# test cost:  0.031561197526752946 test accuracy:  0.020999999716877937
# Next_Train----------: step =  4900
# train_cost:  0.0012856793706305324 train_accuracy:  0.051999999396502974
# test cost:  0.031628472916781905 test accuracy:  0.021999999694526196
# Next_Train----------: step =  4950
# train_cost:  0.0011259984428761527 train_accuracy:  0.04299999941140413
# test cost:  0.03182227555662394 test accuracy:  0.020999999530613423
# Next_Train----------: step =  5000
# train_cost:  0.0011206514114746823 train_accuracy:  0.04499999918043614
# test cost:  0.031883432902395724 test accuracy:  0.017999999597668646
