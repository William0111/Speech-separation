# %% [markdown]
# # Simple RNN test by data-3*512
# # 5000 steps with lr = 0.01 (relatively big learning rate)

# %% [markdown]
# Results are better than
# best run:

# %%
import numpy as np

np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import SimpleRNN, Activation, Dense, Flatten,LSTM, TimeDistributed
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.optimizers import RMSprop

TIME_STEPS = 3
INPUT_SIZE = 512
BATCH_SIZE = 50
BATCH_INDEX = 0
OUTPUT_SIZE = 1536
#CELL_SIZE = 800
LR = 0.01


           
           
# loading data
X_train = np.loadtxt("0126_spec_train_1000.txt")
y_train = np.loadtxt("0126_mask_train_1000.txt")

X_test = np.loadtxt("0126_spec_test_1000.txt")
y_test = np.loadtxt("0126_mask_test_1000.txt")

# batch_size=y_test.shape[0]

# data pre-processing
X_train = X_train.reshape(-1, 3, 512)
#y_train = y_train.reshape(-1, 3, 512)
X_test = X_test.reshape(-1, 3, 512)
#y_test = y_test.reshape(-1, 3, 512)

#  build RNN model
model = Sequential()

# RNN cell

model.add(LSTM(
    units =1536,
    batch_input_shape=( BATCH_SIZE, TIME_STEPS, INPUT_SIZE),
    #input_dim=INPUT_SIZE,
    #input_length=TIME_STEPS,
    #output_dim=CELL_SIZE,
    #return_sequences=True,
    #stateful=True 
    unroll=True
))

# output layer
#model.add(Flatten())
model.add((Dense(OUTPUT_SIZE)))  #TimeDistributed
#model.add(Activation('hard_sigmoid'))

# # optimizer
#
adam = Adam(LR)

#optimizer
#rmsprop = RMSprop(lr=0.0001, rho=0.9, epsilon=1e-8, decay=0.0)

model.compile(optimizer=adam,
              loss='mse',
              metrics=['accuracy'])

# # training
#

for step in range(5001):
    # data shape = (batch_num, steps, inputs/outputs)
    X_batch = X_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :, :]
    Y_batch = y_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :]
    cost = model.train_on_batch(X_batch, Y_batch)
    BATCH_INDEX += BATCH_SIZE
    BATCH_INDEX = 0 if BATCH_INDEX >= X_train.shape[0] else BATCH_INDEX

    if step % 50 == 0:
        print('Next_Train----------: step = ', step)
        train_cost, train_accuracy = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=False)
        print('train_cost: ', train_cost, 'train_accuracy: ', train_accuracy)
        cost, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=False)
        print('test cost: ', cost, 'test accuracy: ', accuracy)
        
       

# print('Train-------------------------')
#
# history = model.fit(X_train, y_train, validation_split=0.25, epochs=3100, shuffle=True, batch_size=75, verbose=1)
#
# # Plot training & validation accuracy values
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# # Plot training & validation loss values
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# get_3rd_layer_output = K.function([model.layers[0].input],
#                                   [model.layers[1].output])
# layer_output1 = get_3rd_layer_output([X_train])[0]
#
# print(layer_output1)
# Out:
# /home/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Next_Train----------: step =  0
# train_cost:  0.03507272750139236 train_accuracy:  0.004999999888241291
# test cost:  0.04112667748704553 test accuracy:  0.007999999821186066
# Next_Train----------: step =  50
# train_cost:  0.024337596958503127 train_accuracy:  0.024999999441206455
# test cost:  0.03124876953661442 test accuracy:  0.012999999709427357
# Next_Train----------: step =  100
# train_cost:  0.01943050972186029 train_accuracy:  0.021999999508261682
# test cost:  0.027965477015823127 test accuracy:  0.008999999798834323
# Next_Train----------: step =  150
# train_cost:  0.016368660191074014 train_accuracy:  0.029999999329447746
# test cost:  0.02758776694536209 test accuracy:  0.014999999664723873
# Next_Train----------: step =  200
# train_cost:  0.0144611488096416 train_accuracy:  0.018999999575316905
# test cost:  0.027168533485382795 test accuracy:  0.010999999754130841
# Next_Train----------: step =  250
# train_cost:  0.012657212186604738 train_accuracy:  0.021999999508261682
# test cost:  0.027492867689579724 test accuracy:  0.011999999731779098
# Next_Train----------: step =  300
# train_cost:  0.012444628030061721 train_accuracy:  0.011999999731779098
# test cost:  0.02802396733313799 test accuracy:  0.011999999731779098
# Next_Train----------: step =  350
# train_cost:  0.010488491598516702 train_accuracy:  0.022999999485909937
# test cost:  0.027890786156058313 test accuracy:  0.014999999664723873
# Next_Train----------: step =  400
# train_cost:  0.009181466489098965 train_accuracy:  0.021999999508261682
# test cost:  0.027181099355220794 test accuracy:  0.012999999709427357
# Next_Train----------: step =  450
# train_cost:  0.010277240606956183 train_accuracy:  0.020999999530613423
# test cost:  0.03162968792021274 test accuracy:  0.014999999664723873
# Next_Train----------: step =  500
# train_cost:  0.009046275145374238 train_accuracy:  0.02799999937415123
# test cost:  0.02883038856089115 test accuracy:  0.015999999642372132
# Next_Train----------: step =  550
# train_cost:  0.007709987694397569 train_accuracy:  0.023999999463558196
# test cost:  0.028243144787847996 test accuracy:  0.02599999960511923
# Next_Train----------: step =  600
# train_cost:  0.007621575403027237 train_accuracy:  0.014999999664723873
# test cost:  0.029025212861597538 test accuracy:  0.010999999754130841
# Next_Train----------: step =  650
# train_cost:  0.006022912543267011 train_accuracy:  0.018999999575316905
# test cost:  0.028393697179853915 test accuracy:  0.014999999664723873
# Next_Train----------: step =  700
# train_cost:  0.005252391018439084 train_accuracy:  0.02399999964982271
# test cost:  0.02930609155446291 test accuracy:  0.023999999463558196
# Next_Train----------: step =  750
# train_cost:  0.004310761112719774 train_accuracy:  0.021999999508261682
# test cost:  0.028945843409746885 test accuracy:  0.021999999508261682
# Next_Train----------: step =  800
# train_cost:  0.003964248020201922 train_accuracy:  0.017999999597668646
# test cost:  0.029325463250279425 test accuracy:  0.014999999664723873
# Next_Train----------: step =  850
# train_cost:  0.0035822698380798103 train_accuracy:  0.022999999485909937
# test cost:  0.029566477984189987 test accuracy:  0.017999999597668646
# Next_Train----------: step =  900
# train_cost:  0.00364213059656322 train_accuracy:  0.04299999941140413
# test cost:  0.029776880610734226 test accuracy:  0.022999999485909937
# Next_Train----------: step =  950
# train_cost:  0.0034544393769465388 train_accuracy:  0.025999999418854714
# test cost:  0.02961680982261896 test accuracy:  0.01699999962002039
# Next_Train----------: step =  1000
# train_cost:  0.0033867441292386503 train_accuracy:  0.025999999418854714
# test cost:  0.029973629023879768 test accuracy:  0.012999999709427357
# Next_Train----------: step =  1050
# train_cost:  0.002942127001006156 train_accuracy:  0.03999999910593033
# test cost:  0.029018698912113904 test accuracy:  0.007999999821186066
# Next_Train----------: step =  1100
# train_cost:  0.0028381709242239596 train_accuracy:  0.022999999485909937
# test cost:  0.0288935374468565 test accuracy:  0.009999999776482582
# Next_Train----------: step =  1150
# train_cost:  0.0027369883784558622 train_accuracy:  0.022999999485909937
# test cost:  0.028848584927618503 test accuracy:  0.010999999754130841
# Next_Train----------: step =  1200
# train_cost:  0.002287963288836181 train_accuracy:  0.024999999441206455
# test cost:  0.02846239199861884 test accuracy:  0.010999999754130841
# Next_Train----------: step =  1250
# train_cost:  0.0020965750503819437 train_accuracy:  0.022999999485909937
# test cost:  0.029053670074790715 test accuracy:  0.014999999664723873
# Next_Train----------: step =  1300
# train_cost:  0.0021179445466259494 train_accuracy:  0.0409999992698431
# test cost:  0.028467434272170068 test accuracy:  0.011999999731779098
# Next_Train----------: step =  1350
# train_cost:  0.002207357593579218 train_accuracy:  0.038999999314546584
# test cost:  0.02888062670826912 test accuracy:  0.014999999664723873
# Next_Train----------: step =  1400
# train_cost:  0.0021464476478286086 train_accuracy:  0.039999999292194846
# test cost:  0.029436423163861036 test accuracy:  0.015999999642372132
# Next_Train----------: step =  1450
# train_cost:  0.0018712023855186998 train_accuracy:  0.04799999929964542
# test cost:  0.029176127351820468 test accuracy:  0.012999999709427357
# Next_Train----------: step =  1500
# train_cost:  0.0016188803769182415 train_accuracy:  0.03299999926239252
# test cost:  0.02954027187079191 test accuracy:  0.012999999709427357
# Next_Train----------: step =  1550
# train_cost:  0.0015599881939124317 train_accuracy:  0.038999999314546584
# test cost:  0.029820260219275953 test accuracy:  0.012999999709427357
# Next_Train----------: step =  1600
# train_cost:  0.0016393599362345412 train_accuracy:  0.024999999441206455
# test cost:  0.02977304384112358 test accuracy:  0.010999999754130841
# Next_Train----------: step =  1650
# train_cost:  0.0015902959275990725 train_accuracy:  0.029999999701976775
# test cost:  0.029288702178746462 test accuracy:  0.014999999664723873
# Next_Train----------: step =  1700
# train_cost:  0.0015012350457254797 train_accuracy:  0.036999999545514584
# test cost:  0.02883092947304249 test accuracy:  0.011999999731779098
# Next_Train----------: step =  1750
# train_cost:  0.0015132796484977006 train_accuracy:  0.04299999941140413
# test cost:  0.028925391659140588 test accuracy:  0.017999999597668646
# Next_Train----------: step =  1800
# train_cost:  0.0017421402415493503 train_accuracy:  0.043999999202787875
# test cost:  0.028717774711549283 test accuracy:  0.012999999709427357
# Next_Train----------: step =  1850
# train_cost:  0.001642464112956077 train_accuracy:  0.07699999902397395
# test cost:  0.030050773080438374 test accuracy:  0.019999999552965164
# Next_Train----------: step =  1900
# train_cost:  0.0015523245441727341 train_accuracy:  0.03299999926239252
# test cost:  0.030085835512727498 test accuracy:  0.014999999664723873
# Next_Train----------: step =  1950
# train_cost:  0.0011765862902393565 train_accuracy:  0.04699999950826168
# test cost:  0.02913761353120208 test accuracy:  0.01699999962002039
# Next_Train----------: step =  2000
# train_cost:  0.0011958270042669028 train_accuracy:  0.038999999314546584
# test cost:  0.02903489824384451 test accuracy:  0.01699999962002039
# Next_Train----------: step =  2050
# train_cost:  0.0012753834918839857 train_accuracy:  0.04799999929964542
# test cost:  0.029532495699822903 test accuracy:  0.014999999664723873
# Next_Train----------: step =  2100
# train_cost:  0.0013143843389116228 train_accuracy:  0.09099999982863664
# test cost:  0.029759522061794996 test accuracy:  0.024999999441206455
# Next_Train----------: step =  2150
# train_cost:  0.0012565807963255792 train_accuracy:  0.0800000000745058
# test cost:  0.0295276558957994 test accuracy:  0.027999999560415746
# Next_Train----------: step =  2200
# train_cost:  0.001550019151181914 train_accuracy:  0.04999999906867743
# test cost:  0.029539078660309314 test accuracy:  0.017999999597668646
# Next_Train----------: step =  2250
# train_cost:  0.0016923953080549836 train_accuracy:  0.03799999915063381
# test cost:  0.02893771594390273 test accuracy:  0.024999999441206455
# Next_Train----------: step =  2300
# train_cost:  0.0015572610835079103 train_accuracy:  0.046999999321997166
# test cost:  0.028964709024876356 test accuracy:  0.021999999694526196
# Next_Train----------: step =  2350
# train_cost:  0.001475292188115418 train_accuracy:  0.05999999903142452
# test cost:  0.029709332250058652 test accuracy:  0.022999999485909937
# Next_Train----------: step =  2400
# train_cost:  0.001712120184674859 train_accuracy:  0.06799999922513962
# test cost:  0.03001270443201065 test accuracy:  0.03299999926239252
# Next_Train----------: step =  2450
# train_cost:  0.0019368290406418965 train_accuracy:  0.048999999463558194
# test cost:  0.03024028204381466 test accuracy:  0.017999999597668646
# Next_Train----------: step =  2500
# train_cost:  0.0012753232484101317 train_accuracy:  0.04999999906867743
# test cost:  0.029698937991634013 test accuracy:  0.02399999964982271
# Next_Train----------: step =  2550
# train_cost:  0.0013828452792949975 train_accuracy:  0.057999999076128
# test cost:  0.029957722686231137 test accuracy:  0.017999999597668646
# Next_Train----------: step =  2600
# train_cost:  0.0010598748485790566 train_accuracy:  0.07099999878555537
# test cost:  0.029107366083189846 test accuracy:  0.029999999329447746
# Next_Train----------: step =  2650
# train_cost:  0.0009930368629284202 train_accuracy:  0.05799999926239252
# test cost:  0.028838912351056935 test accuracy:  0.021999999508261682
# Next_Train----------: step =  2700
# train_cost:  0.0015572269534459338 train_accuracy:  0.07099999971687794
# test cost:  0.029285309463739397 test accuracy:  0.022999999485909937
# Next_Train----------: step =  2750
# train_cost:  0.0012715763587038964 train_accuracy:  0.038999999314546584
# test cost:  0.02986600366421044 test accuracy:  0.020999999530613423
# Next_Train----------: step =  2800
# train_cost:  0.0011007506618625484 train_accuracy:  0.04299999941140413
# test cost:  0.03011651635169983 test accuracy:  0.017999999597668646
# Next_Train----------: step =  2850
# train_cost:  0.0009738971304614097 train_accuracy:  0.04999999925494194
# test cost:  0.029073319770395754 test accuracy:  0.019999999552965164
# Next_Train----------: step =  2900
# train_cost:  0.0009385461962665431 train_accuracy:  0.060999999195337294
# test cost:  0.029512863699346782 test accuracy:  0.019999999552965164
# Next_Train----------: step =  2950
# train_cost:  0.0010574956846539862 train_accuracy:  0.04499999918043614
# test cost:  0.02938873115926981 test accuracy:  0.015999999642372132
# Next_Train----------: step =  3000
# train_cost:  0.001445617972058244 train_accuracy:  0.048999999091029166
# test cost:  0.030239090463146566 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3050
# train_cost:  0.0013632753893034534 train_accuracy:  0.050999999046325684
# test cost:  0.0295426769182086 test accuracy:  0.021999999508261682
# Next_Train----------: step =  3100
# train_cost:  0.0010811696556629613 train_accuracy:  0.04299999922513962
# test cost:  0.02932179132476449 test accuracy:  0.018999999575316905
# Next_Train----------: step =  3150
# train_cost:  0.001039858146396 train_accuracy:  0.04299999922513962
# test cost:  0.029870061203837395 test accuracy:  0.021999999508261682
# Next_Train----------: step =  3200
# train_cost:  0.0010856906374101527 train_accuracy:  0.05599999912083149
# test cost:  0.029970780899748205 test accuracy:  0.022999999672174455
# Next_Train----------: step =  3250
# train_cost:  0.0011245395289734006 train_accuracy:  0.03599999919533729
# test cost:  0.029880501981824636 test accuracy:  0.014999999664723873
# Next_Train----------: step =  3300
# train_cost:  0.0013620818252093158 train_accuracy:  0.038999999314546584
# test cost:  0.030406930204480886 test accuracy:  0.019999999552965164
# Next_Train----------: step =  3350
# train_cost:  0.0015226304851239548 train_accuracy:  0.05699999909847975
# test cost:  0.02990428013727069 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3400
# train_cost:  0.0012687145557720215 train_accuracy:  0.05999999903142452
# test cost:  0.029187650326639412 test accuracy:  0.015999999642372132
# Next_Train----------: step =  3450
# train_cost:  0.0008351169031811878 train_accuracy:  0.03599999938160181
# test cost:  0.029005285259336232 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3500
# train_cost:  0.0008666650617669802 train_accuracy:  0.0509999992325902
# test cost:  0.029922159481793643 test accuracy:  0.027999999560415746
# Next_Train----------: step =  3550
# train_cost:  0.0012543172502773813 train_accuracy:  0.053999999165534975
# test cost:  0.02954745842143893 test accuracy:  0.03099999949336052
# Next_Train----------: step =  3600
# train_cost:  0.0009108990707318299 train_accuracy:  0.046999999694526194
# test cost:  0.029736253339797257 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3650
# train_cost:  0.0005109532030473929 train_accuracy:  0.04999999925494194
# test cost:  0.029159333417192103 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3700
# train_cost:  0.0004582859779475257 train_accuracy:  0.043999999202787875
# test cost:  0.029179768916219474 test accuracy:  0.022999999485909937
# Next_Train----------: step =  3750
# train_cost:  0.00042941654319292864 train_accuracy:  0.036999999359250066
# test cost:  0.02934204610064626 test accuracy:  0.022999999485909937
# Next_Train----------: step =  3800
# train_cost:  0.0004236606626363937 train_accuracy:  0.036999999172985555
# test cost:  0.029347184160724283 test accuracy:  0.022999999485909937
# Next_Train----------: step =  3850
# train_cost:  0.00047284509128076024 train_accuracy:  0.0909999992698431
# test cost:  0.029291982250288128 test accuracy:  0.025999999418854714
# Next_Train----------: step =  3900
# train_cost:  0.0004880000211414881 train_accuracy:  0.057999999076128
# test cost:  0.029425220051780342 test accuracy:  0.025999999418854714
# Next_Train----------: step =  3950
# train_cost:  0.0006102514205849729 train_accuracy:  0.05299999956041575
# test cost:  0.029626814741641284 test accuracy:  0.023999999463558196
# Next_Train----------: step =  4000
# train_cost:  0.0007868183383834548 train_accuracy:  0.05499999914318323
# test cost:  0.02928764414973557 test accuracy:  0.02999999951571226
# Next_Train----------: step =  4050
# train_cost:  0.0006676482225884683 train_accuracy:  0.04399999938905239
# test cost:  0.02982874298468232 test accuracy:  0.028999999351799487
# Next_Train----------: step =  4100
# train_cost:  0.0009679473500000313 train_accuracy:  0.057999999076128
# test cost:  0.029478837829083206 test accuracy:  0.02599999960511923
# Next_Train----------: step =  4150
# train_cost:  0.0010704434433137066 train_accuracy:  0.05099999941885471
# test cost:  0.029207845125347374 test accuracy:  0.02399999964982271
# Next_Train----------: step =  4200
# train_cost:  0.0009827188521740026 train_accuracy:  0.04699999913573265
# test cost:  0.029360433248803018 test accuracy:  0.02799999937415123
# Next_Train----------: step =  4250
# train_cost:  0.0007664752585696988 train_accuracy:  0.03299999944865704
# test cost:  0.0295319733209908 test accuracy:  0.018999999575316905
# Next_Train----------: step =  4300
# train_cost:  0.0007023203317658045 train_accuracy:  0.02999999951571226
# test cost:  0.029112145351246 test accuracy:  0.028999999351799487
# Next_Train----------: step =  4350
# train_cost:  0.0008358654347830452 train_accuracy:  0.028999999351799487
# test cost:  0.0294760518707335 test accuracy:  0.024999999441206455
# Next_Train----------: step =  4400
# train_cost:  0.0009653566390625201 train_accuracy:  0.046999999694526194
# test cost:  0.029604028258472682 test accuracy:  0.024999999441206455
# Next_Train----------: step =  4450
# train_cost:  0.0008031168094021268 train_accuracy:  0.04699999894946814
# test cost:  0.029525935463607312 test accuracy:  0.021999999508261682
# Next_Train----------: step =  4500
# train_cost:  0.0008798383089015261 train_accuracy:  0.03799999952316284
# test cost:  0.029957415536046028 test accuracy:  0.023999999463558196
# Next_Train----------: step =  4550
# train_cost:  0.0013146203331416474 train_accuracy:  0.03999999910593033
# test cost:  0.0309456302318722 test accuracy:  0.023999999463558196
# Next_Train----------: step =  4600
# train_cost:  0.0013285120774526149 train_accuracy:  0.04999999906867743
# test cost:  0.030866941902786493 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4650
# train_cost:  0.0009413931868039072 train_accuracy:  0.053999999165534975
# test cost:  0.030277382349595428 test accuracy:  0.02599999960511923
# Next_Train----------: step =  4700
# train_cost:  0.0007068203965900465 train_accuracy:  0.03599999919533729
# test cost:  0.030123064387589694 test accuracy:  0.023999999463558196
# Next_Train----------: step =  4750
# train_cost:  0.0007123675721231848 train_accuracy:  0.04699999950826168
# test cost:  0.02963065803050995 test accuracy:  0.02399999964982271
# Next_Train----------: step =  4800
# train_cost:  0.0007985279109561816 train_accuracy:  0.041999999061226846
# test cost:  0.029700619401410222 test accuracy:  0.026999999582767487
# Next_Train----------: step =  4850
# train_cost:  0.0005821248007123359 train_accuracy:  0.03799999915063381
# test cost:  0.029508275678381324 test accuracy:  0.018999999575316905
# Next_Train----------: step =  4900
# train_cost:  0.0005295257273246534 train_accuracy:  0.05899999961256981
# test cost:  0.02973680910654366 test accuracy:  0.027999999560415746
# Next_Train----------: step =  4950
# train_cost:  0.00047281581282732077 train_accuracy:  0.06499999929219484
# test cost:  0.03000202840194106 test accuracy:  0.028999999351799487
# Next_Train----------: step =  5000
# train_cost:  0.00047445598465856165 train_accuracy:  0.05199999883770943
# test cost:  0.029597699642181396 test accuracy:  0.024999999441206455
