# %% [markdown]
# # Simple RNN test by data-3*512
# # 5000 steps with lr = 0.001

# %% [markdown]
# Results are better than
# best run:

# %%
import numpy as np

np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import SimpleRNN, Activation, Dense, Flatten,LSTM, TimeDistributed
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.optimizers import RMSprop

TIME_STEPS = 3
INPUT_SIZE = 512
BATCH_SIZE = 50
BATCH_INDEX = 0
OUTPUT_SIZE = 1536
#CELL_SIZE = 800
LR = 0.001


           
           
# loading data
X_train = np.loadtxt("0126_spec_train_1000.txt")
y_train = np.loadtxt("0126_mask_train_1000.txt")

X_test = np.loadtxt("0126_spec_test_1000.txt")
y_test = np.loadtxt("0126_mask_test_1000.txt")

# batch_size=y_test.shape[0]

# data pre-processing
X_train = X_train.reshape(-1, 3, 512)
#y_train = y_train.reshape(-1, 3, 512)
X_test = X_test.reshape(-1, 3, 512)
#y_test = y_test.reshape(-1, 3, 512)

#  build RNN model
model = Sequential()

# RNN cell

model.add(LSTM(
    units =1536,
    batch_input_shape=( BATCH_SIZE, TIME_STEPS, INPUT_SIZE),
    #input_dim=INPUT_SIZE,
    #input_length=TIME_STEPS,
    #output_dim=CELL_SIZE,
    #return_sequences=True,
    #stateful=True 
    unroll=True
))

# output layer
#model.add(Flatten())
model.add((Dense(OUTPUT_SIZE)))  #TimeDistributed
#model.add(Activation('hard_sigmoid'))

# # optimizer
#
adam = Adam(LR)

#optimizer
#rmsprop = RMSprop(lr=0.0001, rho=0.9, epsilon=1e-8, decay=0.0)

model.compile(optimizer=adam,
              loss='mse',
              metrics=['accuracy'])

# # training
#

for step in range(5001):
    # data shape = (batch_num, steps, inputs/outputs)
    X_batch = X_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :, :]
    Y_batch = y_train[BATCH_INDEX: BATCH_INDEX + BATCH_SIZE, :]
    cost = model.train_on_batch(X_batch, Y_batch)
    BATCH_INDEX += BATCH_SIZE
    BATCH_INDEX = 0 if BATCH_INDEX >= X_train.shape[0] else BATCH_INDEX

    if step % 50 == 0:
        print('Next_Train----------: step = ', step)
        train_cost, train_accuracy = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=False)
        print('train_cost: ', train_cost, 'train_accuracy: ', train_accuracy)
        cost, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=False)
        print('test cost: ', cost, 'test accuracy: ', accuracy)
        
       

# print('Train-------------------------')
#
# history = model.fit(X_train, y_train, validation_split=0.25, epochs=3100, shuffle=True, batch_size=75, verbose=1)
#
# # Plot training & validation accuracy values
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# # Plot training & validation loss values
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
#
# get_3rd_layer_output = K.function([model.layers[0].input],
#                                   [model.layers[1].output])
# layer_output1 = get_3rd_layer_output([X_train])[0]
#
# print(layer_output1)
# Out:
# /home/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Next_Train----------: step =  0
# train_cost:  0.03650525137782097 train_accuracy:  0.0029999999329447745
# test cost:  0.04413241883739829 test accuracy:  0.0029999999329447745
# Next_Train----------: step =  50
# train_cost:  0.02139111515134573 train_accuracy:  0.020999999716877937
# test cost:  0.029023744445294142 test accuracy:  0.013999999687075614
# Next_Train----------: step =  100
# train_cost:  0.0186115812510252 train_accuracy:  0.02999999951571226
# test cost:  0.026709588710218668 test accuracy:  0.012999999709427357
# Next_Train----------: step =  150
# train_cost:  0.01703218761831522 train_accuracy:  0.026999999582767487
# test cost:  0.02653383733704686 test accuracy:  0.017999999597668646
# Next_Train----------: step =  200
# train_cost:  0.016010009776800872 train_accuracy:  0.028999999351799487
# test cost:  0.025924617517739536 test accuracy:  0.014999999664723873
# Next_Train----------: step =  250
# train_cost:  0.01464562569744885 train_accuracy:  0.03299999926239252
# test cost:  0.026088322512805462 test accuracy:  0.01899999976158142
# Next_Train----------: step =  300
# train_cost:  0.01422103396616876 train_accuracy:  0.034999999403953555
# test cost:  0.026301239104941487 test accuracy:  0.021999999508261682
# Next_Train----------: step =  350
# train_cost:  0.013051870930939912 train_accuracy:  0.031999999284744264
# test cost:  0.026241266075521706 test accuracy:  0.01899999976158142
# Next_Train----------: step =  400
# train_cost:  0.012374458578415215 train_accuracy:  0.02799999937415123
# test cost:  0.025909706437960266 test accuracy:  0.019999999552965164
# Next_Train----------: step =  450
# train_cost:  0.01138219644781202 train_accuracy:  0.028999999351799487
# test cost:  0.025864716758951543 test accuracy:  0.012999999709427357
# Next_Train----------: step =  500
# train_cost:  0.011106066405773163 train_accuracy:  0.0419999998062849
# test cost:  0.025269714090973137 test accuracy:  0.01999999973922968
# Next_Train----------: step =  550
# train_cost:  0.010474904836155475 train_accuracy:  0.020999999530613423
# test cost:  0.02668548533692956 test accuracy:  0.013999999687075614
# Next_Train----------: step =  600
# train_cost:  0.009506413037888706 train_accuracy:  0.018999999575316905
# test cost:  0.02587071992456913 test accuracy:  0.011999999731779098
# Next_Train----------: step =  650
# train_cost:  0.00892772909719497 train_accuracy:  0.025999999418854714
# test cost:  0.026263550482690336 test accuracy:  0.024999999441206455
# Next_Train----------: step =  700
# train_cost:  0.008643600600771606 train_accuracy:  0.015999999642372132
# test cost:  0.02625689166598022 test accuracy:  0.01699999962002039
# Next_Train----------: step =  750
# train_cost:  0.00792014750186354 train_accuracy:  0.018999999575316905
# test cost:  0.02611248381435871 test accuracy:  0.023999999463558196
# Next_Train----------: step =  800
# train_cost:  0.007471203641034663 train_accuracy:  0.023999999463558196
# test cost:  0.026760798739269377 test accuracy:  0.022999999672174455
# Next_Train----------: step =  850
# train_cost:  0.007096425816416741 train_accuracy:  0.023999999463558196
# test cost:  0.027014257106930017 test accuracy:  0.023999999463558196
# Next_Train----------: step =  900
# train_cost:  0.006916934158653021 train_accuracy:  0.01699999962002039
# test cost:  0.02672115550376475 test accuracy:  0.01699999962002039
# Next_Train----------: step =  950
# train_cost:  0.006400015461258591 train_accuracy:  0.023999999463558196
# test cost:  0.027278971020132305 test accuracy:  0.017999999597668646
# Next_Train----------: step =  1000
# train_cost:  0.006399377214256674 train_accuracy:  0.03299999926239252
# test cost:  0.027795377047732474 test accuracy:  0.028999999351799487
# Next_Train----------: step =  1050
# train_cost:  0.005605467665009201 train_accuracy:  0.030999999307096005
# test cost:  0.02707530977204442 test accuracy:  0.026999999396502973
# Next_Train----------: step =  1100
# train_cost:  0.005368608271237463 train_accuracy:  0.028999999351799487
# test cost:  0.027005962282419204 test accuracy:  0.026999999582767487
# Next_Train----------: step =  1150
# train_cost:  0.004714754759334028 train_accuracy:  0.03399999942630529
# test cost:  0.027556333225220442 test accuracy:  0.02799999937415123
# Next_Train----------: step =  1200
# train_cost:  0.004502233921084553 train_accuracy:  0.03499999921768904
# test cost:  0.027729191072285175 test accuracy:  0.028999999538064
# Next_Train----------: step =  1250
# train_cost:  0.004296492040157318 train_accuracy:  0.03299999944865704
# test cost:  0.027893794560804964 test accuracy:  0.031999999284744264
# Next_Train----------: step =  1300
# train_cost:  0.004615332756657153 train_accuracy:  0.028999999351799487
# test cost:  0.02921515014022589 test accuracy:  0.025999999418854714
# Next_Train----------: step =  1350
# train_cost:  0.004078710626345128 train_accuracy:  0.036999999359250066
# test cost:  0.02850167090073228 test accuracy:  0.03299999926239252
# Next_Train----------: step =  1400
# train_cost:  0.004843645496293902 train_accuracy:  0.030999999679625034
# test cost:  0.027873504534363748 test accuracy:  0.02799999937415123
# Next_Train----------: step =  1450
# train_cost:  0.0043419612920843065 train_accuracy:  0.03299999926239252
# test cost:  0.027383460942655802 test accuracy:  0.026999999396502973
# Next_Train----------: step =  1500
# train_cost:  0.003886381455231458 train_accuracy:  0.025999999418854714
# test cost:  0.027459991723299028 test accuracy:  0.028999999351799487
# Next_Train----------: step =  1550
# train_cost:  0.0033893354586325584 train_accuracy:  0.025999999418854714
# test cost:  0.02758363392204046 test accuracy:  0.023999999463558196
# Next_Train----------: step =  1600
# train_cost:  0.0028585013817064462 train_accuracy:  0.038999999314546584
# test cost:  0.02803412200883031 test accuracy:  0.029999999329447746
# Next_Train----------: step =  1650
# train_cost:  0.0025939145241864027 train_accuracy:  0.028999999351799487
# test cost:  0.02825124394148588 test accuracy:  0.026999999396502973
# Next_Train----------: step =  1700
# train_cost:  0.002487676835153252 train_accuracy:  0.036999999172985555
# test cost:  0.028815451264381408 test accuracy:  0.028999999351799487
# Next_Train----------: step =  1750
# train_cost:  0.0023777416558004917 train_accuracy:  0.0409999992698431
# test cost:  0.028816031571477652 test accuracy:  0.03499999921768904
# Next_Train----------: step =  1800
# train_cost:  0.0025274992978665976 train_accuracy:  0.03399999942630529
# test cost:  0.02928557563573122 test accuracy:  0.03399999924004078
# Next_Train----------: step =  1850
# train_cost:  0.0023579282511491328 train_accuracy:  0.03399999924004078
# test cost:  0.029266425874084234 test accuracy:  0.028999999351799487
# Next_Train----------: step =  1900
# train_cost:  0.002556909940904006 train_accuracy:  0.03799999915063381
# test cost:  0.029218714125454424 test accuracy:  0.030999999307096005
# Next_Train----------: step =  1950
# train_cost:  0.00237655530218035 train_accuracy:  0.05099999941885471
# test cost:  0.028541251178830863 test accuracy:  0.03299999926239252
# Next_Train----------: step =  2000
# train_cost:  0.002374231058638543 train_accuracy:  0.03399999942630529
# test cost:  0.029225628171116114 test accuracy:  0.028999999351799487
# Next_Train----------: step =  2050
# train_cost:  0.0026531586714554577 train_accuracy:  0.04799999911338091
# test cost:  0.029945828951895237 test accuracy:  0.03599999919533729
# Next_Train----------: step =  2100
# train_cost:  0.0024855668540112673 train_accuracy:  0.0429999990388751
# test cost:  0.02989070825278759 test accuracy:  0.029999999329447746
# Next_Train----------: step =  2150
# train_cost:  0.002024388435529545 train_accuracy:  0.03599999919533729
# test cost:  0.029322092700749636 test accuracy:  0.026999999396502973
# Next_Train----------: step =  2200
# train_cost:  0.002029195218347013 train_accuracy:  0.034999999403953555
# test cost:  0.029336587991565466 test accuracy:  0.023999999463558196
# Next_Train----------: step =  2250
# train_cost:  0.0022148775111418217 train_accuracy:  0.03799999933689833
# test cost:  0.029518418479710817 test accuracy:  0.031999999284744264
# Next_Train----------: step =  2300
# train_cost:  0.0025602624227758497 train_accuracy:  0.034999999403953555
# test cost:  0.02884968826547265 test accuracy:  0.024999999441206455
# Next_Train----------: step =  2350
# train_cost:  0.0020084377843886613 train_accuracy:  0.034999999590218066
# test cost:  0.029074160661548377 test accuracy:  0.023999999463558196
# Next_Train----------: step =  2400
# train_cost:  0.0018052460043691098 train_accuracy:  0.0419999998062849
# test cost:  0.028995985630899668 test accuracy:  0.025999999418854714
# Next_Train----------: step =  2450
# train_cost:  0.0015645393810700624 train_accuracy:  0.061999999545514585
# test cost:  0.028970273118466137 test accuracy:  0.03599999919533729
# Next_Train----------: step =  2500
# train_cost:  0.0014860769151709974 train_accuracy:  0.04199999924749136
# test cost:  0.029218055307865143 test accuracy:  0.022999999485909937
# Next_Train----------: step =  2550
# train_cost:  0.001331046034465544 train_accuracy:  0.028999999538064
# test cost:  0.029522079415619372 test accuracy:  0.031999999284744264
# Next_Train----------: step =  2600
# train_cost:  0.0013439446309348568 train_accuracy:  0.057999999076128
# test cost:  0.029291895404458045 test accuracy:  0.02799999937415123
# Next_Train----------: step =  2650
# train_cost:  0.001218347653048113 train_accuracy:  0.06199999898672104
# test cost:  0.029441015142947436 test accuracy:  0.029999999329447746
# Next_Train----------: step =  2700
# train_cost:  0.0013083008903777226 train_accuracy:  0.04399999938905239
# test cost:  0.029802200198173524 test accuracy:  0.024999999441206455
# Next_Train----------: step =  2750
# train_cost:  0.0013231424207333475 train_accuracy:  0.05599999912083149
# test cost:  0.03005390418693423 test accuracy:  0.022999999485909937
# Next_Train----------: step =  2800
# train_cost:  0.0013710619328776374 train_accuracy:  0.041999999433755875
# test cost:  0.02951287729665637 test accuracy:  0.026999999396502973
# Next_Train----------: step =  2850
# train_cost:  0.0013305496395332739 train_accuracy:  0.05399999972432852
# test cost:  0.02935229381546378 test accuracy:  0.023999999463558196
# Next_Train----------: step =  2900
# train_cost:  0.001280281803337857 train_accuracy:  0.05799999888986349
# test cost:  0.02906292015686631 test accuracy:  0.031999999471008775
# Next_Train----------: step =  2950
# train_cost:  0.0012203337624669074 train_accuracy:  0.056999999843537805
# test cost:  0.02910433951765299 test accuracy:  0.025999999418854714
# Next_Train----------: step =  3000
# train_cost:  0.0013726309320190922 train_accuracy:  0.05299999937415123
# test cost:  0.029176306445151567 test accuracy:  0.027999999560415746
# Next_Train----------: step =  3050
# train_cost:  0.0012014145526336507 train_accuracy:  0.059999999962747096
# test cost:  0.029146843403577805 test accuracy:  0.030999999307096005
# Next_Train----------: step =  3100
# train_cost:  0.0011378846713341773 train_accuracy:  0.048999999277293683
# test cost:  0.029425061121582986 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3150
# train_cost:  0.0010061346838483587 train_accuracy:  0.06099999975413084
# test cost:  0.02933467095717788 test accuracy:  0.03299999926239252
# Next_Train----------: step =  3200
# train_cost:  0.000953303869755473 train_accuracy:  0.04999999925494194
# test cost:  0.029333110246807338 test accuracy:  0.022999999672174455
# Next_Train----------: step =  3250
# train_cost:  0.0009331043431302533 train_accuracy:  0.03399999942630529
# test cost:  0.029535647854208945 test accuracy:  0.024999999441206455
# Next_Train----------: step =  3300
# train_cost:  0.000980107874784153 train_accuracy:  0.04499999899417162
# test cost:  0.029646926932036875 test accuracy:  0.026999999396502973
# Next_Train----------: step =  3350
# train_cost:  0.0009319722128566354 train_accuracy:  0.05799999963492155
# test cost:  0.029930824972689153 test accuracy:  0.031999999284744264
# Next_Train----------: step =  3400
# train_cost:  0.001038875148515217 train_accuracy:  0.04299999922513962
# test cost:  0.029682667460292578 test accuracy:  0.02599999960511923
# Next_Train----------: step =  3450
# train_cost:  0.001046753372065723 train_accuracy:  0.03799999915063381
# test cost:  0.029583706706762313 test accuracy:  0.022999999485909937
# Next_Train----------: step =  3500
# train_cost:  0.0012200502649648115 train_accuracy:  0.043999999202787875
# test cost:  0.029296713648363948 test accuracy:  0.021999999508261682
# Next_Train----------: step =  3550
# train_cost:  0.0009586975764250382 train_accuracy:  0.036999999545514584
# test cost:  0.028617870062589645 test accuracy:  0.021999999508261682
# Next_Train----------: step =  3600
# train_cost:  0.0011320518795400857 train_accuracy:  0.06699999962002039
# test cost:  0.028889587614685297 test accuracy:  0.021999999508261682
# Next_Train----------: step =  3650
# train_cost:  0.0009849533729720862 train_accuracy:  0.03799999933689833
# test cost:  0.028949057403951883 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3700
# train_cost:  0.0012481452082283794 train_accuracy:  0.04099999945610762
# test cost:  0.028839657176285984 test accuracy:  0.020999999530613423
# Next_Train----------: step =  3750
# train_cost:  0.0011237889266340062 train_accuracy:  0.048999999277293683
# test cost:  0.02826866218820214 test accuracy:  0.02599999960511923
# Next_Train----------: step =  3800
# train_cost:  0.0010667258669855074 train_accuracy:  0.05499999914318323
# test cost:  0.028439006116241217 test accuracy:  0.024999999441206455
# Next_Train----------: step =  3850
# train_cost:  0.0007972447390784509 train_accuracy:  0.04799999911338091
# test cost:  0.02872456032782793 test accuracy:  0.022999999485909937
# Next_Train----------: step =  3900
# train_cost:  0.0006598264502827078 train_accuracy:  0.0689999993890524
# test cost:  0.029159118607640266 test accuracy:  0.023999999463558196
# Next_Train----------: step =  3950
# train_cost:  0.0005679849782609381 train_accuracy:  0.058999999426305294
# test cost:  0.029768002312630416 test accuracy:  0.022999999485909937
# Next_Train----------: step =  4000
# train_cost:  0.0006094505763030611 train_accuracy:  0.039999999664723875
# test cost:  0.029313757736235856 test accuracy:  0.023999999463558196
# Next_Train----------: step =  4050
# train_cost:  0.0006280831832555123 train_accuracy:  0.04199999924749136
# test cost:  0.029011253081262112 test accuracy:  0.021999999508261682
# Next_Train----------: step =  4100
# train_cost:  0.0005672752609825693 train_accuracy:  0.06599999871104956
# test cost:  0.02900113919749856 test accuracy:  0.030999999307096005
# Next_Train----------: step =  4150
# train_cost:  0.0005235707751126029 train_accuracy:  0.0689999993890524
# test cost:  0.029055784456431866 test accuracy:  0.025999999418854714
# Next_Train----------: step =  4200
# train_cost:  0.0005315186092047953 train_accuracy:  0.06099999900907278
# test cost:  0.02888960437849164 test accuracy:  0.02499999962747097
# Next_Train----------: step =  4250
# train_cost:  0.0004908395014354028 train_accuracy:  0.07299999985843897
# test cost:  0.02903939103707671 test accuracy:  0.026999999582767487
# Next_Train----------: step =  4300
# train_cost:  0.0005063019714725669 train_accuracy:  0.07599999886006117
# test cost:  0.02905695913359523 test accuracy:  0.025999999418854714
# Next_Train----------: step =  4350
# train_cost:  0.00042798424838110807 train_accuracy:  0.07200000006705523
# test cost:  0.029354187659919262 test accuracy:  0.023999999463558196
# Next_Train----------: step =  4400
# train_cost:  0.0004303529436583631 train_accuracy:  0.05299999937415123
# test cost:  0.029283779300749303 test accuracy:  0.019999999552965164
# Next_Train----------: step =  4450
# train_cost:  0.0004675098796724342 train_accuracy:  0.06799999922513962
# test cost:  0.029499252047389745 test accuracy:  0.02599999960511923
# Next_Train----------: step =  4500
# train_cost:  0.0005876915201952215 train_accuracy:  0.06499999910593032
# test cost:  0.029614033922553063 test accuracy:  0.02499999962747097
# Next_Train----------: step =  4550
# train_cost:  0.0007314957794733346 train_accuracy:  0.03799999952316284
# test cost:  0.029376497492194176 test accuracy:  0.020999999530613423
# Next_Train----------: step =  4600
# train_cost:  0.0008955511962994933 train_accuracy:  0.07999999895691871
# test cost:  0.029432490281760693 test accuracy:  0.031999999471008775
# Next_Train----------: step =  4650
# train_cost:  0.0006699636491248384 train_accuracy:  0.06199999935925007
# test cost:  0.029495876189321278 test accuracy:  0.020999999530613423
# Next_Train----------: step =  4700
# train_cost:  0.0008309133438160643 train_accuracy:  0.05599999912083149
# test cost:  0.029709833581000565 test accuracy:  0.019999999552965164
# Next_Train----------: step =  4750
# train_cost:  0.001094210147857666 train_accuracy:  0.038999999314546584
# test cost:  0.03014795109629631 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4800
# train_cost:  0.0010333802478271537 train_accuracy:  0.04699999988079071
# test cost:  0.029661926627159118 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4850
# train_cost:  0.0006260590409510769 train_accuracy:  0.048999999277293683
# test cost:  0.028761645685881375 test accuracy:  0.01699999962002039
# Next_Train----------: step =  4900
# train_cost:  0.0005047542683314532 train_accuracy:  0.05799999926239252
# test cost:  0.028375121764838696 test accuracy:  0.02799999937415123
# Next_Train----------: step =  4950
# train_cost:  0.00040972586866701023 train_accuracy:  0.041999999061226846
# test cost:  0.028523682337254285 test accuracy:  0.015999999642372132
# Next_Train----------: step =  5000
# train_cost:  0.0003575647569959983 train_accuracy:  0.07499999925494194
# test cost:  0.028819062002003192 test accuracy:  0.02799999937415123
